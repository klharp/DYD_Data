# %% [markdown]
# # DYD Thermostat Data
#
# ## Preprocess
#
# 1. Generated CSV file from queries in BigQueary
#
# 2. Data separated into states
#
# 3. Aggregated the data in Pandas by month
#
# 4. Combine 4 years
#
# 5. Group by Identifier

# %%
# Dependencies
import pandas as pd
import os
import numpy as np
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ---
# ## January

# %% [markdown]
# ### 2017 January Day

# %%
# Read in month csv for state
jan_2017 = pd.read_csv("../data_large/OK-day/2017-jan-day-OK.csv")

# jan_2017

# %%
# Add year and month

jan_2017["Year"] = "2017"
jan_2017["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-01-13 14:45:00 UTC
# 1       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-01-14 18:55:00 UTC
# 2       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-01-31 16:45:00 UTC
# 3       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-01-27 15:35:00 UTC
# 4       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-01-21 16:45:00 UTC
# ...                                          ...                      ...
# 123510  95e6e173a73a61d36c58ff008bf6f3e04dc6b628  2017-01-07 14:20:00 UTC
# 123511  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-01-03 19:50:00 UTC
# 123512  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-01-09 15:15:00 UTC
# 123513  95e6e173a73a61d36c58ff008bf6f3e04dc6b628  2017-01-29 18:20:00 UTC
# 123514  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-01-04 15:25:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jan_2017_ave = jan_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2017_ave

# %%
# Export CSV file

jan_2017_ave.to_csv("data/day/OK/jan/jan_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 January Day

# %%
# Read in month csv for state
jan_2018 = pd.read_csv("../data_large/OK-day/2018-jan-day-OK.csv")

# jan_2018

# %%
# Add year and month

jan_2018["Year"] = "2018"
jan_2018["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       ba715f9c63c29913847598623f037bf4945a120c  2018-01-31 15:05:00 UTC
# 1       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2018-01-28 13:05:00 UTC
# 2       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2018-01-12 13:25:00 UTC
# 3       37b0ede697a4ed2e7f88a6e5248a1d0f29eddd2a  2018-01-29 13:45:00 UTC
# 4       438fafb0cef308d95f28b8e1af2dd207c141941f  2018-01-21 19:15:00 UTC
# ...                                          ...                      ...
# 298987  e214d7a00c4d46d83be3e77f13ca8b83e5105ece  2018-01-14 13:35:00 UTC
# 298988  e214d7a00c4d46d83be3e77f13ca8b83e5105ece  2018-01-04 17:40:00 UTC
# 298989  e214d7a00c4d46d83be3e77f13ca8b83e5105ece  2018-01-05 15:30:00 UTC
# 298990  e214d7a00c4d46d83be3e77f13ca8b83e5105ece  2018-01-13 14:15:00 UTC
# 298991  e214d7a00c4d46d83be3e77f13ca8b83e5105ece  2018-01-09 17:40:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jan_2018_ave = jan_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2018_ave

# %%
# Export CSV file

jan_2018_ave.to_csv("data/day/OK/jan/jan_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 January Day

# %%
# Read in month csv for state
jan_2019 = pd.read_csv("../data_large/OK-day/2019-jan-day-OK.csv")

# jan_2019

# %%
# Add year and month

jan_2019["Year"] = "2019"
jan_2019["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-01-30 13:45:00 UTC
# 1       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-01-31 17:10:00 UTC
# 2       923e530f12f2e2455839d11205eee0fc738473a8  2019-01-15 18:05:00 UTC
# 3       923e530f12f2e2455839d11205eee0fc738473a8  2019-01-17 16:40:00 UTC
# 4       438fafb0cef308d95f28b8e1af2dd207c141941f  2019-01-16 18:15:00 UTC
# ...                                          ...                      ...
# 399040  524ba766836c77bbf96732e5152050986acb457f  2019-01-02 19:15:00 UTC
# 399041  524ba766836c77bbf96732e5152050986acb457f  2019-01-02 19:30:00 UTC
# 399042  e23aa2b1cd4b7a2e4d3bbcdc05a15e7dca4a6504  2019-01-13 18:55:00 UTC
# 399043  524ba766836c77bbf96732e5152050986acb457f  2019-01-02 19:20:00 UTC
# 399044  e23aa2b1cd4b7a2e4d3bbcdc05a15e7dca4a6504  2019-01-13 18:40:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jan_2019_ave = jan_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2019_ave

# %%
# Export CSV file

jan_2019_ave.to_csv("data/day/OK/jan/jan_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 January Day

# %%
# Read in month csv for state
jan_2020 = pd.read_csv("../data_large/OK-day/2020-jan-day-OK.csv")

# jan_2020

# %%
# Add year and month

jan_2020["Year"] = "2020"
jan_2020["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2020-01-10 13:50:00 UTC
# 1       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2020-01-08 13:45:00 UTC
# 2       1b3e9bfbd413d51f1f3d51a8c750f9e2fa2a0a10  2020-01-12 17:35:00 UTC
# 3       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2020-01-06 14:55:00 UTC
# 4       5e07f5c52d96d219e19187fd7895ed8a446d6d89  2020-01-11 19:05:00 UTC
# ...                                          ...                      ...
# 487295  e549ff4e45dc073d518dd3239c81c6a4811ee070  2020-01-05 13:05:00 UTC
# 487296  bb1434eeba7cb4f64db9ba714544a01b1004ee01  2020-01-22 12:40:00 UTC
# 487297  e470e7635bdf00eb642cf6d3fd2c327c9e09502c  2020-01-11 19:35:00 UTC
# 487298  e470e7635bdf00eb642cf6d3fd2c327c9e09502c  2020-01-11 18:55:00 UTC
# 487299  bb1434eeba7cb4f64db9ba714544a01b1004ee01  2020-01-22 12:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jan_2020_ave = jan_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2020_ave

# %%
# Export CSV file

jan_2020_ave.to_csv("data/day/OK/jan/jan_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 January Day

# %%
# Read in month csv for state
jan_2021 = pd.read_csv("../data_large/OK-day/2021-jan-day-OK.csv")

# jan_2021

# %%
# Add year and month

jan_2021["Year"] = "2021"
jan_2021["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2021-01-17 13:25:00 UTC
# 1       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2021-01-11 17:45:00 UTC
# 2       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2021-01-10 13:15:00 UTC
# 3       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2021-01-29 12:45:00 UTC
# 4       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2021-01-20 12:20:00 UTC
# ...                                          ...                      ...
# 304084  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2021-01-25 16:00:00 UTC
# 304085  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2021-01-25 19:45:00 UTC
# 304086  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2021-01-25 16:45:00 UTC
# 304087  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2021-01-27 16:40:00 UTC
# 304088  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2021-01-18 14:15:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jan_2021_ave = jan_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2021_ave

# %%
# Export CSV file

jan_2021_ave.to_csv("data/day/OK/jan/jan_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/jan/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_jan = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/jan/" + file)
    OK_jan = pd.concat([OK_jan, df])
    
OK_jan
# Out:
#                                    Identifier Month  Year     HvacMode  \
# 0    02cfd2f65ec21abb498029a8bb918bef31a65d40   Jan  2017         auto
# 1    02cfd2f65ec21abb498029a8bb918bef31a65d40   Jan  2017         auto
# 2    03268a602de07ff76e632d29d6aea52bfdff06cd   Jan  2017         heat
# 3    03268a602de07ff76e632d29d6aea52bfdff06cd   Jan  2017         heat
# 4    03805b489bdaf90ef55e9a987fd33d9d1ae738a4   Jan  2017  auxHeatOnly
# ..                                        ...   ...   ...          ...
# 440  fc9df3eb40761f8e939ff9b285fff0225880d5a0   Jan  2021         heat
# 441  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   Jan  2021         auto
# 442  fd02028d183495c66db36ea303f49728cab2309d   Jan  2021         auto
# 443  feffbde8a5c9ee59b9161163af900aa9b6ba7000   Jan  2021         auto
# 444  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   Jan  2021         heat
#
#     CalendarEvent       City  Temperature_ctrl  TemperatureExpectedCool  \
# ...

# %%
OK_jan.to_csv("Scraper_Output/State_Month_Day/OK/OK_jan.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## February

# %% [markdown]
# ### 2017 February Day

# %%
# Read in month csv for state
feb_2017 = pd.read_csv("../data_large/OK-day/2017-feb-day-OK.csv")

# feb_2017

# %%
# Add year and month

feb_2017["Year"] = "2017"
feb_2017["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-02-03 15:15:00 UTC
# 1       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-02-02 19:30:00 UTC
# 2       3e7c4870ca3ecd58cdaefb0c91d0fb3fb534bdf4  2017-02-22 11:40:00 UTC
# 3       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-02-06 18:35:00 UTC
# 4       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-02-02 17:45:00 UTC
# ...                                          ...                      ...
# 108745  09c43a5fec14b8459dd8459048d4d7061f3950ca  2017-02-12 19:25:00 UTC
# 108746  09c43a5fec14b8459dd8459048d4d7061f3950ca  2017-02-15 13:50:00 UTC
# 108747  09c43a5fec14b8459dd8459048d4d7061f3950ca  2017-02-15 13:00:00 UTC
# 108748  09c43a5fec14b8459dd8459048d4d7061f3950ca  2017-02-15 13:20:00 UTC
# 108749  09c43a5fec14b8459dd8459048d4d7061f3950ca  2017-02-15 13:20:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
feb_2017_ave = feb_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2017_ave

# %%
# Export CSV file

feb_2017_ave.to_csv("data/day/OK/feb/feb_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 February Day

# %%
# Read in month csv for state
feb_2018 = pd.read_csv("../data_large/OK-day/2018-feb-day-OK.csv")

# feb_2018

# %%
# Add year and month

feb_2018["Year"] = "2018"
feb_2018["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       d2ebfa58f67bf493e147ec73a4a5d92ffc005a47  2018-02-12 18:05:00 UTC
# 1       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2018-02-18 14:25:00 UTC
# 2       37b0ede697a4ed2e7f88a6e5248a1d0f29eddd2a  2018-02-03 18:15:00 UTC
# 3       1e8a3661e74ce17a1f36096eda0ff69b1b73b9b5  2018-02-03 19:35:00 UTC
# 4       37b0ede697a4ed2e7f88a6e5248a1d0f29eddd2a  2018-02-01 07:20:00 UTC
# ...                                          ...                      ...
# 276977  56ad1d86693ad088a94dc40ffc174c7483ec172f  2018-02-19 15:45:00 UTC
# 276978  56ad1d86693ad088a94dc40ffc174c7483ec172f  2018-02-20 12:35:00 UTC
# 276979  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-02-07 14:50:00 UTC
# 276980  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-02-01 15:40:00 UTC
# 276981  56ad1d86693ad088a94dc40ffc174c7483ec172f  2018-02-19 17:35:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
feb_2018_ave = feb_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2018_ave

# %%
# Export CSV file

feb_2018_ave.to_csv("data/day/OK/feb/feb_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 February Day

# %%
# Read in month csv for state
feb_2019 = pd.read_csv("../data_large/OK-day/2019-feb-day-OK.csv")

# feb_2019

# %%
# Add year and month

feb_2019["Year"] = "2019"
feb_2019["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       b5cdcf58c61f32884d567bca5239b9617fa20ee6  2019-02-28 16:05:00 UTC
# 1       88230ea5b8ee1cc52951c7d3fde7e442802c4fa0  2019-02-12 19:15:00 UTC
# 2       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-02-15 13:20:00 UTC
# 3       66e8d5805224fffcbcebe3f1c9c243463331677f  2019-02-23 17:50:00 UTC
# 4       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-02-05 15:45:00 UTC
# ...                                          ...                      ...
# 274388  8646fa6a05cb4ebd41199839d513469c5d3fd612  2019-02-23 19:50:00 UTC
# 274389  524ba766836c77bbf96732e5152050986acb457f  2019-02-26 16:40:00 UTC
# 274390  8646fa6a05cb4ebd41199839d513469c5d3fd612  2019-02-23 15:55:00 UTC
# 274391  8646fa6a05cb4ebd41199839d513469c5d3fd612  2019-02-23 16:25:00 UTC
# 274392  524ba766836c77bbf96732e5152050986acb457f  2019-02-26 16:55:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
feb_2019_ave = feb_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2019_ave

# %%
# Export CSV file

feb_2019_ave.to_csv("data/day/OK/feb/feb_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 February Day

# %%
# Read in month csv for state
feb_2020 = pd.read_csv("../data_large/OK-day/2020-feb-day-OK.csv")

# feb_2020

# %%
# Add year and month

feb_2020["Year"] = "2020"
feb_2020["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2020-02-19 08:30:00 UTC
# 1       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2020-02-23 15:45:00 UTC
# 2       129481ff85aa61c1b7bef570e3799780160ebca7  2020-02-07 14:25:00 UTC
# 3       978babe17a1342659cd1ec7d66427ae262629cf2  2020-02-26 11:15:00 UTC
# 4       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2020-02-10 17:05:00 UTC
# ...                                          ...                      ...
# 436673  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-02-23 14:00:00 UTC
# 436674  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-02-24 15:05:00 UTC
# 436675  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-02-14 17:05:00 UTC
# 436676  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-02-18 12:55:00 UTC
# 436677  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-02-23 15:40:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
feb_2020_ave = feb_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2020_ave

# %%
# Export CSV file

feb_2020_ave.to_csv("data/day/OK/feb/feb_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 February Day

# %%
# Read in month csv for state
feb_2021 = pd.read_csv("../data_large/OK-day/2021-feb-day-OK.csv")

# feb_2021

# %%
# Add year and month

feb_2021["Year"] = "2021"
feb_2021["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2021-02-09 19:30:00 UTC
# 1       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2021-02-14 14:50:00 UTC
# 2       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2021-02-05 17:30:00 UTC
# 3       38581d0405f548128e196ba2e37043a9c1d3edf5  2021-02-01 08:10:00 UTC
# 4       e5829b79fba62ee4b2ff53e69b0cca78de6eecfc  2021-02-10 15:20:00 UTC
# ...                                          ...                      ...
# 259224  7d643735ad1b1810ef1dcb213030764d06c18e8f  2021-02-15 19:05:00 UTC
# 259225  7d643735ad1b1810ef1dcb213030764d06c18e8f  2021-02-16 19:35:00 UTC
# 259226  7d643735ad1b1810ef1dcb213030764d06c18e8f  2021-02-16 19:20:00 UTC
# 259227  7d643735ad1b1810ef1dcb213030764d06c18e8f  2021-02-16 19:55:00 UTC
# 259228  7d643735ad1b1810ef1dcb213030764d06c18e8f  2021-02-16 18:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
feb_2021_ave = feb_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2021_ave

# %%
# Export CSV file

feb_2021_ave.to_csv("data/day/OK/feb/feb_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/feb/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_feb = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/feb/" + file)
    OK_feb = pd.concat([OK_feb, df])
    
OK_feb
# Out:
#                                    Identifier Month  Year HvacMode  \
# 0    02cfd2f65ec21abb498029a8bb918bef31a65d40   feb  2017     auto
# 1    03268a602de07ff76e632d29d6aea52bfdff06cd   feb  2017     auto
# 2    03268a602de07ff76e632d29d6aea52bfdff06cd   feb  2017     cool
# 3    03268a602de07ff76e632d29d6aea52bfdff06cd   feb  2017     heat
# 4    03268a602de07ff76e632d29d6aea52bfdff06cd   feb  2017     heat
# ..                                        ...   ...   ...      ...
# 461  fc9df3eb40761f8e939ff9b285fff0225880d5a0   feb  2021     heat
# 462  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   feb  2021     auto
# 463  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   feb  2021     heat
# 464  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   feb  2021     heat
# 465  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   feb  2021     auto
#
#     CalendarEvent       City  Temperature_ctrl  TemperatureExpectedCool  \
# 0            hold     Salina        759.518519               785.506173
# ...

# %%
OK_feb.to_csv("Scraper_Output/State_Month_Day/OK/OK_feb.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## March

# %% [markdown]
# ---
#
# ## April

# %% [markdown]
# ---
#
# ## May

# %% [markdown]
# ---
#
# ## June

# %% [markdown]
# ### 2017 June Day

# %%
# Read in month csv for state
jun_2017 = pd.read_csv("../data_large/OK-day/2017-jun-day-OK.csv")

# jun_2017

# %%
# Add year and month

jun_2017["Year"] = "2017"
jun_2017["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       23f289088ed76384c831d143d82307206f98c14e  2017-06-12 16:20:00 UTC
# 1       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-06-06 12:40:00 UTC
# 2       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2017-06-19 15:00:00 UTC
# 3       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2017-06-10 15:15:00 UTC
# 4       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2017-06-19 17:05:00 UTC
# ...                                          ...                      ...
# 178933  d038dcc17e44b2ca11f57cb162df1de4e3046548  2017-06-08 11:00:00 UTC
# 178934  56ad1d86693ad088a94dc40ffc174c7483ec172f  2017-06-08 12:15:00 UTC
# 178935  dc94ba1732bbc5219faf6eea148240114493f53f  2017-06-03 18:00:00 UTC
# 178936  56ad1d86693ad088a94dc40ffc174c7483ec172f  2017-06-03 12:55:00 UTC
# 178937  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-06-29 18:05:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jun_2017_ave = jun_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2017_ave

# %%
# Export CSV file

jun_2017_ave.to_csv("data/day/OK/jun/jun_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 June Day

# %%
# Read in month csv for state
jun_2018 = pd.read_csv("../data_large/OK-day/2018-jun-day-OK.csv")

# jun_2018

# %%
# Add year and month

jun_2018["Year"] = "2018"
jun_2018["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       507d058095b6c17499fee91574ecb72c5e99dbb4  2018-06-02 19:55:00 UTC
# 1       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-06-26 18:50:00 UTC
# 2       507d058095b6c17499fee91574ecb72c5e99dbb4  2018-06-30 15:30:00 UTC
# 3       507d058095b6c17499fee91574ecb72c5e99dbb4  2018-06-03 13:55:00 UTC
# 4       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-06-12 19:45:00 UTC
# ...                                          ...                      ...
# 327753  b8634fceafbd537bb000218d925ff5b719d9939b  2018-06-24 18:10:00 UTC
# 327754  dbed761f78870134a35503324de46c3cd2554737  2018-06-24 15:35:00 UTC
# 327755  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-06-15 17:05:00 UTC
# 327756  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-06-11 14:50:00 UTC
# 327757  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-06-13 17:55:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jun_2018_ave = jun_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2018_ave

# %%
# Export CSV file

jun_2018_ave.to_csv("data/day/OK/jun/jun_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 June Day

# %%
# Read in month csv for state
jun_2019 = pd.read_csv("../data_large/OK-day/2019-jun-day-OK.csv")

# jun_2019

# %%
# Add year and month

jun_2019["Year"] = "2019"
jun_2019["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       076fe762a6e0c1bd2edcd4e2e71a6f8cca159fe6  2019-06-10 13:50:00 UTC
# 1       076fe762a6e0c1bd2edcd4e2e71a6f8cca159fe6  2019-06-16 15:30:00 UTC
# 2       1c6ce8b48b0b29dd621115289dfbc5f965dee240  2019-06-19 19:30:00 UTC
# 3       1c6ce8b48b0b29dd621115289dfbc5f965dee240  2019-06-11 19:35:00 UTC
# 4       076fe762a6e0c1bd2edcd4e2e71a6f8cca159fe6  2019-06-12 16:40:00 UTC
# ...                                          ...                      ...
# 480224  a5bde50bf911493d52e0477fc76434257507ee5c  2019-06-25 19:25:00 UTC
# 480225  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2019-06-04 12:30:00 UTC
# 480226  61416071c4caee50c3c0a44077634b010d80930a  2019-06-23 16:05:00 UTC
# 480227  a5bde50bf911493d52e0477fc76434257507ee5c  2019-06-15 19:00:00 UTC
# 480228  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2019-06-11 15:00:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jun_2019_ave = jun_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2019_ave

# %%
# Export CSV file

jun_2019_ave.to_csv("data/day/OK/jun/jun_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 June Day

# %%
# Read in month csv for state
jun_2020 = pd.read_csv("../data_large/OK-day/2020-jun-day-OK.csv")

# jun_2020

# %%
# Add year and month

jun_2020["Year"] = "2020"
jun_2020["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       2c4dda41f17aa45c8041d329487d4a4826f02417  2020-06-24 10:10:00 UTC
# 1       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2020-06-13 15:35:00 UTC
# 2       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2020-06-24 19:50:00 UTC
# 3       88230ea5b8ee1cc52951c7d3fde7e442802c4fa0  2020-06-13 18:40:00 UTC
# 4       978babe17a1342659cd1ec7d66427ae262629cf2  2020-06-20 12:05:00 UTC
# ...                                          ...                      ...
# 499075  aba5ea3faf196db48c716d9493b64cc6e5f32eb1  2020-06-21 15:50:00 UTC
# 499076  f7e4430ae27a45b40fd0a8cde1b36ec7a12c1dc9  2020-06-07 15:40:00 UTC
# 499077  aba5ea3faf196db48c716d9493b64cc6e5f32eb1  2020-06-25 11:35:00 UTC
# 499078  d9d463b893fbfe30d3b93fd3e69524e4604b5d24  2020-06-21 17:20:00 UTC
# 499079  aba5ea3faf196db48c716d9493b64cc6e5f32eb1  2020-06-16 11:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jun_2020_ave = jun_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2020_ave

# %%
# Export CSV file

jun_2020_ave.to_csv("data/day/OK/jun/jun_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 June Day

# %%
# Read in month csv for state
jun_2021 = pd.read_csv("../data_large/OK-day/2021-jun-day-OK.csv")

# jun_2021

# %%
# Add year and month

jun_2021["Year"] = "2021"
jun_2021["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       3e7c4870ca3ecd58cdaefb0c91d0fb3fb534bdf4  2021-06-14 18:35:00 UTC
# 1       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2021-06-12 18:50:00 UTC
# 2       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2021-06-09 11:35:00 UTC
# 3       2ea62f619c12141e20cad967db9ce0af1fc67126  2021-06-10 16:30:00 UTC
# 4       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2021-06-12 13:50:00 UTC
# ...                                          ...                      ...
# 284307  39177cac92e96a2ce8d17265c669702baf173097  2021-06-19 14:35:00 UTC
# 284308  39177cac92e96a2ce8d17265c669702baf173097  2021-06-19 15:35:00 UTC
# 284309  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2021-06-12 19:25:00 UTC
# 284310  875e83afa37d27e5d43dc8dd596cd3e410c28628  2021-06-07 14:10:00 UTC
# 284311  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2021-06-12 17:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jun_2021_ave = jun_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2021_ave

# %%
# Export CSV file

jun_2021_ave.to_csv("data/day/OK/jun/jun_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/jun/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_jun = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/jun/" + file)
    OK_jun = pd.concat([OK_jun, df])
    
OK_jun
# Out:
#                                    Identifier Month  Year HvacMode  \
# 0    02cfd2f65ec21abb498029a8bb918bef31a65d40   jun  2017     auto
# 1    02cfd2f65ec21abb498029a8bb918bef31a65d40   jun  2017     auto
# 2    03268a602de07ff76e632d29d6aea52bfdff06cd   jun  2017     cool
# 3    03268a602de07ff76e632d29d6aea52bfdff06cd   jun  2017     cool
# 4    03805b489bdaf90ef55e9a987fd33d9d1ae738a4   jun  2017     cool
# ..                                        ...   ...   ...      ...
# 441  fc9df3eb40761f8e939ff9b285fff0225880d5a0   jun  2021     cool
# 442  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   jun  2021     auto
# 443  fd6ca4e3809431958eba22fdd62ddfbff3c59a99   jun  2021     cool
# 444  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   jun  2021     cool
# 445  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   jun  2021     auto
#
#     CalendarEvent       City  Temperature_ctrl  TemperatureExpectedCool  \
# 0            auto     Salina        756.852941               757.647059
# ...

# %%
OK_jun.to_csv("Scraper_Output/State_Month_Day/OK/OK_jun.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## July

# %% [markdown]
# ### 2017 July Day

# %%
# Read in month csv for state
jul_2017 = pd.read_csv("../data_large/OK-day/2017-jul-day-OK.csv")

# jul_2017

# %%
# Add year and month

jul_2017["Year"] = "2017"
jul_2017["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       38581d0405f548128e196ba2e37043a9c1d3edf5  2017-07-01 17:15:00 UTC
# 1       38581d0405f548128e196ba2e37043a9c1d3edf5  2017-07-22 18:00:00 UTC
# 2       38581d0405f548128e196ba2e37043a9c1d3edf5  2017-07-29 19:50:00 UTC
# 3       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-07-20 12:55:00 UTC
# 4       38581d0405f548128e196ba2e37043a9c1d3edf5  2017-07-29 19:20:00 UTC
# ...                                          ...                      ...
# 189951  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-07-23 19:00:00 UTC
# 189952  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-07-15 16:50:00 UTC
# 189953  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-07-15 15:35:00 UTC
# 189954  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-07-15 15:25:00 UTC
# 189955  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-07-15 16:40:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jul_2017_ave = jul_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2017_ave

# %%
# Export CSV file

jul_2017_ave.to_csv("data/day/OK/jul/jul_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 July Day

# %%
# Read in month csv for state
jul_2018 = pd.read_csv("../data_large/OK-day/2018-jul-day-OK.csv")

# jul_2018

# %%
# Add year and month

jul_2018["Year"] = "2018"
jul_2018["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       438fafb0cef308d95f28b8e1af2dd207c141941f  2018-07-05 19:45:00 UTC
# 1       438fafb0cef308d95f28b8e1af2dd207c141941f  2018-07-07 14:00:00 UTC
# 2       978babe17a1342659cd1ec7d66427ae262629cf2  2018-07-20 12:10:00 UTC
# 3       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-07-19 15:20:00 UTC
# 4       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-07-22 15:10:00 UTC
# ...                                          ...                      ...
# 373628  7761a2e5f868824dfd37458f47636d07ff01fd2f  2018-07-10 17:35:00 UTC
# 373629  22b294a40318c138a97d7c1ae995397fef5a82d9  2018-07-06 14:15:00 UTC
# 373630  dbed761f78870134a35503324de46c3cd2554737  2018-07-11 17:00:00 UTC
# 373631  dbed761f78870134a35503324de46c3cd2554737  2018-07-16 15:10:00 UTC
# 373632  7761a2e5f868824dfd37458f47636d07ff01fd2f  2018-07-07 16:50:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jul_2018_ave = jul_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2018_ave

# %%
# Export CSV file

jul_2018_ave.to_csv("data/day/OK/jul/jul_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 July Day

# %%
# Read in month csv for state
jul_2019 = pd.read_csv("../data_large/OK-day/2019-jul-day-OK.csv")

# jul_2019

# %%
# Add year and month

jul_2019["Year"] = "2019"
jul_2019["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-07-04 16:50:00 UTC
# 1       2c4dda41f17aa45c8041d329487d4a4826f02417  2019-07-18 12:00:00 UTC
# 2       507d058095b6c17499fee91574ecb72c5e99dbb4  2019-07-04 17:55:00 UTC
# 3       6af6d239121d4d7d328cf09840bce74cda110953  2019-07-09 15:55:00 UTC
# 4       88230ea5b8ee1cc52951c7d3fde7e442802c4fa0  2019-07-01 12:20:00 UTC
# ...                                          ...                      ...
# 507561  516c108e9c2dbdf1df8279ce945bb0551fbe4a6e  2019-07-31 08:50:00 UTC
# 507562  39f9c64bb3c20e5808cc0f1304146fb897384a63  2019-07-05 18:00:00 UTC
# 507563  3767accd42318ed95606c5d58f1c4b35b31c2614  2019-07-31 18:45:00 UTC
# 507564  3767accd42318ed95606c5d58f1c4b35b31c2614  2019-07-31 18:30:00 UTC
# 507565  3767accd42318ed95606c5d58f1c4b35b31c2614  2019-07-31 19:20:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jul_2019_ave = jul_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2019_ave

# %%
# Export CSV file

jul_2019_ave.to_csv("data/day/OK/jul/jul_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 July Day

# %%
# Read in month csv for state
jul_2020 = pd.read_csv("../data_large/OK-day/2020-jul-day-OK.csv")

# jul_2020

# %%
# Add year and month

jul_2020["Year"] = "2020"
jul_2020["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       6af6d239121d4d7d328cf09840bce74cda110953  2020-07-19 15:55:00 UTC
# 1       978babe17a1342659cd1ec7d66427ae262629cf2  2020-07-22 11:15:00 UTC
# 2       978babe17a1342659cd1ec7d66427ae262629cf2  2020-07-18 10:50:00 UTC
# 3       978babe17a1342659cd1ec7d66427ae262629cf2  2020-07-01 09:40:00 UTC
# 4       2a2aa8dc3c77b96fb45e240025d090e0402e7760  2020-07-14 14:00:00 UTC
# ...                                          ...                      ...
# 524236  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-07-16 11:30:00 UTC
# 524237  56ad1d86693ad088a94dc40ffc174c7483ec172f  2020-07-25 12:25:00 UTC
# 524238  56ad1d86693ad088a94dc40ffc174c7483ec172f  2020-07-25 14:45:00 UTC
# 524239  56ad1d86693ad088a94dc40ffc174c7483ec172f  2020-07-01 18:00:00 UTC
# 524240  b8634fceafbd537bb000218d925ff5b719d9939b  2020-07-16 12:50:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jul_2020_ave = jul_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2020_ave

# %%
# Export CSV file

jul_2020_ave.to_csv("data/day/OK/jul/jul_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 July Day

# %%
# Read in month csv for state
jul_2021 = pd.read_csv("../data_large/OK-day/2021-jul-day-OK.csv")

# jul_2021

# %%
# Add year and month

jul_2021["Year"] = "2021"
jul_2021["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       208204937e59d0176286369adea683a808f6fb3a  2021-07-17 18:00:00 UTC
# 1       5f5aba3536cca286724b7a2085b0d323b0a0f075  2021-07-16 14:50:00 UTC
# 2       507d058095b6c17499fee91574ecb72c5e99dbb4  2021-07-08 19:10:00 UTC
# 3       3e7c4870ca3ecd58cdaefb0c91d0fb3fb534bdf4  2021-07-19 19:05:00 UTC
# 4       3e7c4870ca3ecd58cdaefb0c91d0fb3fb534bdf4  2021-07-19 15:05:00 UTC
# ...                                          ...                      ...
# 273038  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2021-07-18 11:10:00 UTC
# 273039  56ad1d86693ad088a94dc40ffc174c7483ec172f  2021-07-09 14:15:00 UTC
# 273040  a61787b382d95c665dae538481c4b1cc5b2c1650  2021-07-03 17:10:00 UTC
# 273041  f554f9ef1a120b50d226dabd11950b02fa199364  2021-07-25 12:15:00 UTC
# 273042  875e83afa37d27e5d43dc8dd596cd3e410c28628  2021-07-01 07:15:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
jul_2021_ave = jul_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2021_ave

# %%
# Export CSV file

jul_2021_ave.to_csv("data/day/OK/jul/jul_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/jul/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_jul = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/jul/" + file)
    OK_jul = pd.concat([OK_jul, df])
    
OK_jul
# Out:
#                                    Identifier Month  Year HvacMode  \
# 0    02cfd2f65ec21abb498029a8bb918bef31a65d40   jul  2017     auto
# 1    03268a602de07ff76e632d29d6aea52bfdff06cd   jul  2017     cool
# 2    03805b489bdaf90ef55e9a987fd33d9d1ae738a4   jul  2017     cool
# 3    03805b489bdaf90ef55e9a987fd33d9d1ae738a4   jul  2017     cool
# 4    043757348c59292de2a957b62f803d46d0a67a14   jul  2017     cool
# ..                                        ...   ...   ...      ...
# 383  fb6aadbf58a2823d0584172150460a7a63359535   jul  2021     cool
# 384  fba1702351c2c3e006851b13a944809101daecc7   jul  2021     auto
# 385  fc9df3eb40761f8e939ff9b285fff0225880d5a0   jul  2021     cool
# 386  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   jul  2021     auto
# 387  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   jul  2021     cool
#
#     CalendarEvent           City  Temperature_ctrl  TemperatureExpectedCool  \
# 0            hold         Salina        754.320675               750.000000
# ...

# %%
OK_jul.to_csv("Scraper_Output/State_Month_Day/OK/OK_jul.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## August

# %% [markdown]
# ### 2017 August Day

# %%
# Read in month csv for state
aug_2017 = pd.read_csv("../data_large/OK-day/2017-aug-day-OK.csv")

# aug_2017

# %%
# Add year and month

aug_2017["Year"] = "2017"
aug_2017["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-08-28 11:35:00 UTC
# 1       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-08-28 13:40:00 UTC
# 2       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-08-28 19:50:00 UTC
# 3       3e7c4870ca3ecd58cdaefb0c91d0fb3fb534bdf4  2017-08-25 12:00:00 UTC
# 4       438fafb0cef308d95f28b8e1af2dd207c141941f  2017-08-28 12:35:00 UTC
# ...                                          ...                      ...
# 195468  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-08-11 17:15:00 UTC
# 195469  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-08-30 17:35:00 UTC
# 195470  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-08-10 17:50:00 UTC
# 195471  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2017-08-31 16:30:00 UTC
# 195472  b3aa185e8b0b650fd372e37a9eb8763d149c61d9  2017-08-05 14:05:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
aug_2017_ave = aug_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2017_ave

# %%
# Export CSV file

aug_2017_ave.to_csv("data/day/OK/aug/aug_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 August Day

# %%
# Read in month csv for state
aug_2018 = pd.read_csv("../data_large/OK-day/2018-aug-day-OK.csv")

# aug_2018

# %%
# Add year and month

aug_2018["Year"] = "2018"
aug_2018["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-08-03 14:50:00 UTC
# 1       55684e7e548f1ef441dd884bf77a6347593b73a6  2018-08-08 14:05:00 UTC
# 2       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-08-28 13:25:00 UTC
# 3       98315d26ac90e6275a3b77392d8b5ceffa5a4dfb  2018-08-03 14:30:00 UTC
# 4       55684e7e548f1ef441dd884bf77a6347593b73a6  2018-08-05 11:50:00 UTC
# ...                                          ...                      ...
# 379572  dbed761f78870134a35503324de46c3cd2554737  2018-08-28 19:30:00 UTC
# 379573  a5bde50bf911493d52e0477fc76434257507ee5c  2018-08-09 12:05:00 UTC
# 379574  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2018-08-28 18:00:00 UTC
# 379575  dbed761f78870134a35503324de46c3cd2554737  2018-08-29 19:00:00 UTC
# 379576  a5bde50bf911493d52e0477fc76434257507ee5c  2018-08-22 17:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
aug_2018_ave = aug_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2018_ave

# %%
# Export CSV file

aug_2018_ave.to_csv("data/day/OK/aug/aug_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 August Day

# %%
# Read in month csv for state
aug_2019 = pd.read_csv("../data_large/OK-day/2019-aug-day-OK.csv")

# aug_2019

# %%
# Add year and month

aug_2019["Year"] = "2019"
aug_2019["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       1c6ce8b48b0b29dd621115289dfbc5f965dee240  2019-08-23 17:35:00 UTC
# 1       076fe762a6e0c1bd2edcd4e2e71a6f8cca159fe6  2019-08-22 17:20:00 UTC
# 2       076fe762a6e0c1bd2edcd4e2e71a6f8cca159fe6  2019-08-20 18:10:00 UTC
# 3       874eb4045787da4810e6a43a32df879100983209  2019-08-11 17:05:00 UTC
# 4       7ff4d3135503e1499b3ef9fc449e849128dc3971  2019-08-10 16:10:00 UTC
# ...                                          ...                      ...
# 536835  653977b6622c2f7e5eb871f58dadbbadd43831ff  2019-08-20 16:50:00 UTC
# 536836  991d3a0f7653318a6829a6a52414efd00ed3eacb  2019-08-04 19:45:00 UTC
# 536837  dbed761f78870134a35503324de46c3cd2554737  2019-08-15 14:25:00 UTC
# 536838  bb1434eeba7cb4f64db9ba714544a01b1004ee01  2019-08-21 12:05:00 UTC
# 536839  bb1434eeba7cb4f64db9ba714544a01b1004ee01  2019-08-21 11:50:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
aug_2019_ave = aug_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2019_ave

# %%
# Export CSV file

aug_2019_ave.to_csv("data/day/OK/aug/aug_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 August Day

# %%
# Read in month csv for state
aug_2020 = pd.read_csv("../data_large/OK-day/2020-aug-day-OK.csv")

# aug_2020

# %%
# Add year and month

aug_2020["Year"] = "2020"
aug_2020["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       978babe17a1342659cd1ec7d66427ae262629cf2  2020-08-23 12:50:00 UTC
# 1       2c4dda41f17aa45c8041d329487d4a4826f02417  2020-08-19 12:05:00 UTC
# 2       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2020-08-15 18:25:00 UTC
# 3       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2020-08-21 13:35:00 UTC
# 4       9ddde5fe6e01a444d2fee506165e2c0bbe546c2a  2020-08-14 15:00:00 UTC
# ...                                          ...                      ...
# 500792  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-08-14 13:10:00 UTC
# 500793  f554f9ef1a120b50d226dabd11950b02fa199364  2020-08-19 19:55:00 UTC
# 500794  3f434fecb86959a50eafe1bea900000fdda379dd  2020-08-26 18:20:00 UTC
# 500795  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2020-08-25 11:40:00 UTC
# 500796  3f434fecb86959a50eafe1bea900000fdda379dd  2020-08-29 15:25:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
aug_2020_ave = aug_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2020_ave

# %%
# Export CSV file

aug_2020_ave.to_csv("data/day/OK/aug/aug_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 August Day

# %%
# # Read in month csv for state
# aug_2021 = pd.read_csv("../data_large/OK-day/2021-aug-day-OK.csv")

# # aug_2021

# %%
# # Add year and month

# aug_2021["Year"] = "2021"
# aug_2021["Month"] = "aug"

# %%
# # Rename columns to label the aggregates

# aug_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
#                          "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
#                          "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
# aug_2021_ave = aug_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# # aug_2021_ave

# %%
# # Export CSV file

# aug_2021_ave.to_csv("data/day/OK/aug/aug_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/aug/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_aug = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/aug/" + file)
    OK_aug = pd.concat([OK_aug, df])
    
OK_aug
# Out:
#                                    Identifier Month  Year HvacMode  \
# 0    01ac10bc02b4056dcba48fe50a960e6423136bee   aug  2017     cool
# 1    02cfd2f65ec21abb498029a8bb918bef31a65d40   aug  2017     auto
# 2    02cfd2f65ec21abb498029a8bb918bef31a65d40   aug  2017     auto
# 3    03268a602de07ff76e632d29d6aea52bfdff06cd   aug  2017     cool
# 4    03268a602de07ff76e632d29d6aea52bfdff06cd   aug  2017     cool
# ..                                        ...   ...   ...      ...
# 724  fd6ca4e3809431958eba22fdd62ddfbff3c59a99   aug  2020     cool
# 725  feffbde8a5c9ee59b9161163af900aa9b6ba7000   aug  2020     auto
# 726  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   aug  2020     cool
# 727  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   aug  2020     cool
# 728  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   aug  2020     auto
#
#     CalendarEvent      City  Temperature_ctrl  TemperatureExpectedCool  \
# 0            auto    Lawton        751.311429               793.025714
# ...

# %%
OK_aug.to_csv("Scraper_Output/State_Month_Day/OK/OK_aug.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## September

# %% [markdown]
# ---
#
# ## October

# %% [markdown]
# ---
#
# ## November

# %% [markdown]
# ---
#
# ## December

# %% [markdown]
# ### 2017 December Day

# %%
# Read in month csv for state
dec_2017 = pd.read_csv("../data_large/OK-day/2017-dec-day-OK.csv")

# dec_2017

# %%
# Add year and month

dec_2017["Year"] = "2017"
dec_2017["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       55684e7e548f1ef441dd884bf77a6347593b73a6  2017-12-24 14:35:00 UTC
# 1       aa7bc4b4f0bac9324242121301c35427ef4d1c55  2017-12-10 13:55:00 UTC
# 2       8d020f3cd215191ae0d481d726ec52c0c0128961  2017-12-30 15:40:00 UTC
# 3       ba715f9c63c29913847598623f037bf4945a120c  2017-12-29 19:05:00 UTC
# 4       8d020f3cd215191ae0d481d726ec52c0c0128961  2017-12-29 18:00:00 UTC
# ...                                          ...                      ...
# 267676  425980103be87fc8cf6198494e451842c85c4e3b  2017-12-19 13:15:00 UTC
# 267677  a5bde50bf911493d52e0477fc76434257507ee5c  2017-12-15 16:30:00 UTC
# 267678  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2017-12-30 19:40:00 UTC
# 267679  b5bc061e5f1b097b0aaaa82bfd5aa0540830b73a  2017-12-30 19:25:00 UTC
# 267680  425980103be87fc8cf6198494e451842c85c4e3b  2017-12-22 13:10:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
dec_2017_ave = dec_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2017_ave

# %%
# Export CSV file

dec_2017_ave.to_csv("data/day/OK/dec/dec_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 December Day

# %%
# Read in month csv for state
dec_2018 = pd.read_csv("../data_large/OK-day/2018-dec-day-OK.csv")

# dec_2018

# %%
# Add year and month

dec_2018["Year"] = "2018"
dec_2018["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       f4c2c705b341c03851a42c5d6e517e07b39dd645  2018-12-19 17:30:00 UTC
# 1       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2018-12-22 18:10:00 UTC
# 2       3f4f0d340acf2984d073812ab995a7f76aa7080a  2018-12-21 14:55:00 UTC
# 3       978babe17a1342659cd1ec7d66427ae262629cf2  2018-12-29 14:50:00 UTC
# 4       3f4f0d340acf2984d073812ab995a7f76aa7080a  2018-12-21 14:00:00 UTC
# ...                                          ...                      ...
# 401725  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2018-12-14 17:45:00 UTC
# 401726  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2018-12-14 16:10:00 UTC
# 401727  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2018-12-14 17:20:00 UTC
# 401728  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2018-12-14 19:15:00 UTC
# 401729  7ee9451679e6ffc2571213effb6e44a0b6ce0c20  2018-12-14 16:45:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
dec_2018_ave = dec_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2018_ave

# %%
# Export CSV file

dec_2018_ave.to_csv("data/day/OK/dec/dec_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 December Day

# %%
# Read in month csv for state
dec_2019 = pd.read_csv("../data_large/OK-day/2019-dec-day-OK.csv")

# dec_2019

# %%
# Add year and month

dec_2019["Year"] = "2019"
dec_2019["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       1b3e9bfbd413d51f1f3d51a8c750f9e2fa2a0a10  2019-12-13 13:45:00 UTC
# 1       88230ea5b8ee1cc52951c7d3fde7e442802c4fa0  2019-12-21 16:55:00 UTC
# 2       2c4dda41f17aa45c8041d329487d4a4826f02417  2019-12-30 11:35:00 UTC
# 3       b19f0ea499d61c0cc2a72d6476506f84b9a5e496  2019-12-29 15:20:00 UTC
# 4       8ded71afa8afd28638fac6fa23324ecd7c7d746d  2019-12-23 16:10:00 UTC
# ...                                          ...                      ...
# 490226  25dde82d83ce83a2f7b62250d19ffa1c5d747af0  2019-12-22 15:30:00 UTC
# 490227  25dde82d83ce83a2f7b62250d19ffa1c5d747af0  2019-12-24 15:30:00 UTC
# 490228  e549ff4e45dc073d518dd3239c81c6a4811ee070  2019-12-22 12:40:00 UTC
# 490229  25dde82d83ce83a2f7b62250d19ffa1c5d747af0  2019-12-18 14:30:00 UTC
# 490230  25dde82d83ce83a2f7b62250d19ffa1c5d747af0  2019-12-20 12:55:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
dec_2019_ave = dec_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2019_ave

# %%
# Export CSV file

dec_2019_ave.to_csv("data/day/OK/dec/dec_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 December Day

# %%
# Read in month csv for state
dec_2020 = pd.read_csv("../data_large/OK-day/2020-dec-day-OK.csv")

# dec_2020

# %%
# Add year and month

dec_2020["Year"] = "2020"
dec_2020["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})
# Out:
#                                       Identifier                date_time  \
# 0       978babe17a1342659cd1ec7d66427ae262629cf2  2020-12-16 12:35:00 UTC
# 1       2ea62f619c12141e20cad967db9ce0af1fc67126  2020-12-14 17:25:00 UTC
# 2       978babe17a1342659cd1ec7d66427ae262629cf2  2020-12-12 11:10:00 UTC
# 3       e022577714744a916c2693762aa7949d1d258b59  2020-12-29 11:10:00 UTC
# 4       e022577714744a916c2693762aa7949d1d258b59  2020-12-28 11:30:00 UTC
# ...                                          ...                      ...
# 465796  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2020-12-17 13:50:00 UTC
# 465797  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2020-12-13 15:05:00 UTC
# 465798  1c9ecfc97fd23c51ed16dc8233b9cbb82b18212e  2020-12-24 19:30:00 UTC
# 465799  30cc7b8e491ff0ae977450c8ddb143bb95ce0d92  2020-12-18 18:55:00 UTC
# 465800  1c9ecfc97fd23c51ed16dc8233b9cbb82b18212e  2020-12-27 18:25:00 UTC
#
#        HvacMode CalendarEvent  Temperature_ctrl_ave  \
# ...

# %%
dec_2020_ave = dec_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2020_ave

# %%
# Export CSV file

dec_2020_ave.to_csv("data/day/OK/dec/dec_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/OK/dec/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_dec = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/OK/dec/" + file)
    OK_dec = pd.concat([OK_dec, df])
    
OK_dec
# Out:
#                                    Identifier Month  Year HvacMode  \
# 0    01ac10bc02b4056dcba48fe50a960e6423136bee   dec  2017     heat
# 1    01ac10bc02b4056dcba48fe50a960e6423136bee   dec  2017     heat
# 2    0211eaf3110e78dbb0c68b5fe4fa17980427b53b   dec  2017     cool
# 3    0211eaf3110e78dbb0c68b5fe4fa17980427b53b   dec  2017     cool
# 4    0211eaf3110e78dbb0c68b5fe4fa17980427b53b   dec  2017     heat
# ..                                        ...   ...   ...      ...
# 804  fd6ca4e3809431958eba22fdd62ddfbff3c59a99   dec  2020     heat
# 805  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   dec  2020     heat
# 806  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   dec  2020     heat
# 807  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   dec  2020     auto
# 808  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   dec  2020     auto
#
#     CalendarEvent      City  Temperature_ctrl  TemperatureExpectedCool  \
# 0            auto    Lawton        741.752381               749.180952
# ...

# %%
OK_dec.to_csv("Scraper_Output/State_Month_Day/OK/OK_dec.csv", header=True, index=False)

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# ---
#
# ### Combine state CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("Scraper_Output/State_Month_Day/OK/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# InitiOKize and empty dataframe
OK_all = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("Scraper_Output/State_Month_Day/OK/" + file)
    OK_all = pd.concat([OK_all, df])
    
OK_all
# Out:
#                                     Identifier Month  Year HvacMode  \
# 0     01ac10bc02b4056dcba48fe50a960e6423136bee   aug  2017     cool
# 1     02cfd2f65ec21abb498029a8bb918bef31a65d40   aug  2017     auto
# 2     02cfd2f65ec21abb498029a8bb918bef31a65d40   aug  2017     auto
# 3     03268a602de07ff76e632d29d6aea52bfdff06cd   aug  2017     cool
# 4     03268a602de07ff76e632d29d6aea52bfdff06cd   aug  2017     cool
# ...                                        ...   ...   ...      ...
# 2864  fc9df3eb40761f8e939ff9b285fff0225880d5a0   jun  2021     cool
# 2865  fcd13e5a660b968af3b32efd3bfa993ae9ed8b97   jun  2021     auto
# 2866  fd6ca4e3809431958eba22fdd62ddfbff3c59a99   jun  2021     cool
# 2867  ff2348bcd45e2e26549dbdf63cc7fea6c920df3d   jun  2021     cool
# 2868  ffec30f9f8ace8924a98ea7c78f23a55ebf3ff01   jun  2021     auto
#
#      CalendarEvent       City  Temperature_ctrl  TemperatureExpectedCool  \
# 0             auto     Lawton        751.311429               793.025714
# ...

# %%
OK_all.to_csv("Scraper_Output/State_Month_Day/OK_all_day.csv", header=True, index=False)
