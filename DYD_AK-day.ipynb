# %% [markdown]
# # DYD Thermostat Data
#
# ## Preprocess
#
# 1. Generated CSV file from queries in BigQueary
#
# 2. Data separated into states
#
# 3. Aggregated the data in Pandas by month
#
# 4. Combine 4 years
#
# 5. Group by Identifier

# %%
# Dependencies
import pandas as pd
import os
import numpy as np
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ---
# ## January

# %% [markdown]
# ### 2017 January Day

# %%
# Read in month csv for state
jan_2017 = pd.read_csv("../data_large/AK-day/2017-jan-day-AK.csv")

# jan_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jan_2017.drop(jan_2017[jan_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
jan_2017.drop(jan_2017[jan_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jan_2017.drop(jan_2017[jan_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
jan_2017.drop(jan_2017[jan_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jan_2017
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-01-23T08:50:00Z     heat
# 1     14a6f6af23d454bda9e5b09021f63af861c9ab83  2017-01-16T19:45:00Z     heat
# 2     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-01-20T09:05:00Z     heat
# 3     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-01-13T08:40:00Z     heat
# 4     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-01-01T08:45:00Z     heat
# ...                                        ...                   ...      ...
# 6598  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2017-01-07T07:00:00Z     heat
# 6599  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2017-01-07T17:25:00Z     heat
# 6600  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2017-01-07T16:45:00Z     heat
# 6601  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2017-01-07T17:20:00Z     heat
# 6602  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2017-01-07T16:15:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               697                      688
# 1             auto               642                      806
# 2             auto               683                      685
# 3             auto               665                      700
# 4             auto               637                      741
# ...            ...               ...                      ...
# 6598          auto               738                      740
# 6599          auto               737                      740
# 6600          auto               744                      740
# 6601          auto               739                      740
# 6602          auto               734                      740
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         688            AK  Anchorage                    0
# 1                         628            AK  Anchorage                   20
# 2                         681            AK  Anchorage                    0
# 3                         684            AK  Anchorage                    0
# 4                         669            AK  Anchorage                    0
# ...                       ...           ...        ...                  ...
# 6598                      740            AK    Wasilla                    5
# 6599                      740            AK    Wasilla                    5
# 6600                      740            AK    Wasilla                    5
# 6601                      740            AK    Wasilla                    5
# 6602                      740            AK    Wasilla                    5
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 6598             False         False            False
# 6599             False         False            False
# 6600             False         False            False
# 6601             False         False            False
# 6602             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 6598                       Gas
# 6599                       Gas
# 6600                       Gas
# 6601                       Gas
# 6602                       Gas
#
# [5925 rows x 14 columns]

# %%
# Add year and month

jan_2017["Year"] = "2017"
jan_2017["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2017 = jan_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jan_2017_ave = jan_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

jan_2017_ave
# Out:
#                                                                                               Temperature_ctrl_ave  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                    642.000000
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                    642.055556
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                       644.954545
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park            629.122517
#                                                              hold          Russian Jack Park            619.231492
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                      635.125000
#                                                              hold          Chugiak                      635.212766
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                    669.842105
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                        682.669565
#                                                              hold          Healy                        678.985507
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                    674.860140
#                                                              hold          Anchorage                    700.400000
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                      694.287161
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                      690.378840
#                                                              hold          Wasilla                      700.015385
#
#                                                                                               TemperatureExpectedCool_ave  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                           806.000000
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                           780.000000
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                              710.000000
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park                   654.688742
#                                                              hold          Russian Jack Park                   650.071680
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                             655.208333
#                                                              hold          Chugiak                             650.000000
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                           672.631579
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                               700.008696
#                                                              hold          Healy                               687.724638
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                           671.552448
#                                                              hold          Anchorage                           697.600000
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                             695.655315
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                             763.197952
#                                                              hold          Wasilla                             703.780000
#
#                                                                                               TemperatureExpectedHeat_ave  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                           628.000000
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                           650.000000
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                              710.000000
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park                   634.831126
#                                                              hold          Russian Jack Park                   620.521739
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                             638.916667
#                                                              hold          Chugiak                             640.000000
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                           672.631579
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                               685.182609
#                                                              hold          Healy                               686.710145
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                           665.972028
#                                                              hold          Anchorage                           697.600000
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                             695.655315
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                             690.491468
#                                                              hold          Wasilla                             703.647692
#
#                                                                                               Age_of_Home__years_  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                         20.0
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                          5.0
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                             0.0
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park                 20.0
#                                                              hold          Russian Jack Park                 20.0
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                           10.0
#                                                              hold          Chugiak                           10.0
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                         40.0
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                             10.0
#                                                              hold          Healy                             10.0
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                          0.0
#                                                              hold          Anchorage                          0.0
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                            5.0
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                            0.0
#                                                              hold          Wasilla                            0.0
#
#                                                                                               allowCompWithAux  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                     False
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                     False
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                        False
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park             False
#                                                              hold          Russian Jack Park             False
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                        True
#                                                              hold          Chugiak                        True
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                     False
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                         False
#                                                              hold          Healy                         False
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                     False
#                                                              hold          Anchorage                     False
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                       False
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                       False
#                                                              hold          Wasilla                       False
#
#                                                                                               Has_Electric  \
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                 False
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                 False
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                    False
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park         False
#                                                              hold          Russian Jack Park         False
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                   False
#                                                              hold          Chugiak                   False
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                 False
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                     False
#                                                              hold          Healy                     False
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                 False
#                                                              hold          Anchorage                 False
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                   False
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                   False
#                                                              hold          Wasilla                   False
#
#                                                                                               Has_a_Heat_Pump
# Identifier                               Month Year HvacMode CalendarEvent City
# 14a6f6af23d454bda9e5b09021f63af861c9ab83 Jan   2017 heat     auto          Anchorage                    False
# 18c482b133fba9f05f7edac61214d7cd1082ff1a Jan   2017 heat     auto          Anchorage                    False
# 364d90d4305e64cf8a54685a3669aca9ba7667ed Jan   2017 heat     hold          Palmer                       False
# 6085162893ee544ece3ce04e242a68d7a8afe24d Jan   2017 heat     auto          Russian Jack Park            False
#                                                              hold          Russian Jack Park            False
# 81a7bd30ff87a8f606e1378fe9117abbded76a9c Jan   2017 heat     auto          Chugiak                      False
#                                                              hold          Chugiak                      False
# a799538555e2fb23d035a9aa0004122110571484 Jan   2017 heat     hold          Anchorage                    False
# b2926c336f48d0bdbcd5343bb68676b3a9364748 Jan   2017 heat     auto          Healy                        False
#                                                              hold          Healy                        False
# be4f2a63b7719c2a69aa285e8a38038c29df8fa6 Jan   2017 heat     auto          Anchorage                    False
#                                                              hold          Anchorage                    False
# d52d6af22f2bcad8215f8eec1a710dd00e190c7b Jan   2017 heat     auto          Wasilla                      False
# fda1f67e8423ed49933c45617ee96aef3bae04ba Jan   2017 heat     auto          Wasilla                      False
#                                                              hold          Wasilla                      False

# %%
# Export CSV file

jan_2017_ave.to_csv("data/day/AK/jan/jan_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 January Day

# %%
# Read in month csv for state
jan_2018 = pd.read_csv("../data_large/AK-day/2018-jan-day-AK.csv")

# jan_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jan_2018.drop(jan_2018[jan_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
jan_2018.drop(jan_2018[jan_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jan_2018.drop(jan_2018[jan_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
jan_2018.drop(jan_2018[jan_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jan_2018
# Out:
#                                      Identifier             date_time  \
# 0      a799538555e2fb23d035a9aa0004122110571484  2018-01-13T18:40:00Z
# 1      de96ad05755fc1e2697dff5f2548474733554565  2018-01-14T08:25:00Z
# 2      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-01-22T18:30:00Z
# 3      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-01-22T18:00:00Z
# 4      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-01-19T19:35:00Z
# ...                                         ...                   ...
# 13251  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-01-28T19:30:00Z
# 13252  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-01-25T07:15:00Z
# 13253  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-01-26T07:35:00Z
# 13254  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-01-25T16:00:00Z
# 13255  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-01-25T18:40:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               698                      720
# 1         heat          auto               675                      798
# 2         heat          hold               668                      669
# 3         heat          auto               646                      658
# 4         heat          hold               679                      666
# ...        ...           ...               ...                      ...
# 13251     heat          auto               731                      740
# 13252     heat          auto               731                      740
# 13253     heat          auto               735                      740
# 13254     heat          auto               744                      740
# 13255     heat          auto               732                      740
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          695            AK  Anchorage                   40
# 1                          608            AK  Anchorage                   30
# 2                          669            AK      Homer                    0
# 3                          658            AK      Homer                    0
# 4                          661            AK      Homer                    0
# ...                        ...           ...        ...                  ...
# 13251                      740            AK    Wasilla                    5
# 13252                      740            AK    Wasilla                    5
# 13253                      740            AK    Wasilla                    5
# 13254                      740            AK    Wasilla                    5
# 13255                      740            AK    Wasilla                    5
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                  True         False            False
# 3                  True         False            False
# 4                  True         False            False
# ...                 ...           ...              ...
# 13251             False         False            False
# 13252             False         False            False
# 13253             False         False            False
# 13254             False         False            False
# 13255             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 13251                       Gas
# 13252                       Gas
# 13253                       Gas
# 13254                       Gas
# 13255                       Gas
#
# [12473 rows x 14 columns]

# %%
# Add year and month

jan_2018["Year"] = "2018"
jan_2018["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2018 = jan_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jan_2018_ave = jan_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2018_ave

# %%
# Export CSV file

jan_2018_ave.to_csv("data/day/AK/jan/jan_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 January Day

# %%
# Read in month csv for state
jan_2019 = pd.read_csv("../data_large/AK-day/2019-jan-day-AK.csv")

# jan_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jan_2019.drop(jan_2019[jan_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
jan_2019.drop(jan_2019[jan_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jan_2019.drop(jan_2019[jan_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
jan_2019.drop(jan_2019[jan_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jan_2019
# Out:
#                                      Identifier             date_time  \
# 0      a799538555e2fb23d035a9aa0004122110571484  2019-01-07T18:30:00Z
# 1      bdc58f9e6d012d051afe58172dc008bebf29a356  2019-01-06T08:25:00Z
# 2      bdc58f9e6d012d051afe58172dc008bebf29a356  2019-01-05T08:25:00Z
# 3      de96ad05755fc1e2697dff5f2548474733554565  2019-01-20T07:10:00Z
# 4      de96ad05755fc1e2697dff5f2548474733554565  2019-01-06T08:10:00Z
# ...                                         ...                   ...
# 23727  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-01-05T08:10:00Z
# 23728  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-01-05T07:10:00Z
# 23729  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-01-05T07:20:00Z
# 23730  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-01-04T19:25:00Z
# 23731  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-01-05T15:55:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               647                      773
# 1         heat          hold               715                      724
# 2         heat          hold               730                      743
# 3         heat          hold               672                      720
# 4         heat          hold               654                      714
# ...        ...           ...               ...                      ...
# 23727     heat          hold               740                      740
# 23728     heat          hold               736                      740
# 23729     heat          hold               732                      740
# 23730     heat          hold               738                      740
# 23731     heat          hold               745                      740
#
#        TemperatureExpectedHeat ProvinceState              City  \
# 0                          678            AK         Anchorage
# 1                          719            AK  Huffman/O'Malley
# 2                          738            AK  Huffman/O'Malley
# 3                          668            AK         Anchorage
# 4                          662            AK         Anchorage
# ...                        ...           ...               ...
# 23727                      740            AK           Wasilla
# 23728                      740            AK           Wasilla
# 23729                      740            AK           Wasilla
# 23730                      740            AK           Wasilla
# 23731                      740            AK           Wasilla
#
#        Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                       40             False         False            False
# 1                       40             False         False            False
# 2                       40             False         False            False
# 3                       30             False         False            False
# 4                       30             False         False            False
# ...                    ...               ...           ...              ...
# 23727                    5             False         False            False
# 23728                    5             False         False            False
# 23729                    5             False         False            False
# 23730                    5             False         False            False
# 23731                    5             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 23727                       Gas
# 23728                       Gas
# 23729                       Gas
# 23730                       Gas
# 23731                       Gas
#
# [18730 rows x 14 columns]

# %%
# Add year and month

jan_2019["Year"] = "2019"
jan_2019["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2019 = jan_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jan_2019_ave = jan_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2019_ave

# %%
# Export CSV file

jan_2019_ave.to_csv("data/day/AK/jan/jan_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 January Day

# %%
# Read in month csv for state
jan_2020 = pd.read_csv("../data_large/AK-day/2020-jan-day-AK.csv")

# jan_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jan_2020.drop(jan_2020[jan_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
jan_2020.drop(jan_2020[jan_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jan_2020.drop(jan_2020[jan_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
jan_2020.drop(jan_2020[jan_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jan_2020
# Out:
#                                      Identifier             date_time  \
# 0      3f31b8a9942ce423b863741438287d127c6bc39f  2020-01-10T19:10:00Z
# 1      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2020-01-28T07:45:00Z
# 2      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-01-26T08:10:00Z
# 3      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2020-01-03T07:20:00Z
# 4      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-01-26T08:15:00Z
# ...                                         ...                   ...
# 16162  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-01-27T16:00:00Z
# 16163  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-01-27T17:05:00Z
# 16164  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-01-27T15:45:00Z
# 16165  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-01-27T15:30:00Z
# 16166  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-01-27T16:30:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          auto               696                      780
# 1         heat          hold               704                      773
# 2         heat          hold               689                      750
# 3         heat          hold               714                      752
# 4         heat          hold               690                      750
# ...        ...           ...               ...                      ...
# 16162     heat          hold               737                      740
# 16163     heat          hold               731                      740
# 16164     heat          hold               730                      740
# 16165     heat          hold               737                      740
# 16166     heat          hold               736                      740
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          721            AK  Anchorage                   47
# 1                          683            AK     Palmer                   25
# 2                          750            AK  Anchorage                   15
# 3                          692            AK     Palmer                   25
# 4                          750            AK  Anchorage                   15
# ...                        ...           ...        ...                  ...
# 16162                      740            AK  Anchorage                   35
# 16163                      740            AK  Anchorage                   35
# 16164                      740            AK  Anchorage                   35
# 16165                      740            AK  Anchorage                   35
# 16166                      740            AK  Anchorage                   35
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 16162             False         False            False
# 16163             False         False            False
# 16164             False         False            False
# 16165             False         False            False
# 16166             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 16162                       Gas
# 16163                       Gas
# 16164                       Gas
# 16165                       Gas
# 16166                       Gas
#
# [9314 rows x 14 columns]

# %%
# Add year and month

jan_2020["Year"] = "2020"
jan_2020["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2020 = jan_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jan_2020_ave = jan_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2020_ave

# %%
# Export CSV file

jan_2020_ave.to_csv("data/day/AK/jan/jan_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 January Day

# %%
# Read in month csv for state
jan_2021 = pd.read_csv("../data_large/AK-day/2021-jan-day-AK.csv")

# jan_2021

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jan_2021.drop(jan_2021[jan_2021['TemperatureExpectedCool'] >= 850].index, inplace = True)
jan_2021.drop(jan_2021[jan_2021['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jan_2021.drop(jan_2021[jan_2021['TemperatureExpectedCool'] <= 600].index, inplace = True)
jan_2021.drop(jan_2021[jan_2021['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jan_2021
# Out:
#                                      Identifier             date_time  \
# 0      1934269f8f3a7a065318ec9a4e7984c0d9216332  2021-01-26T15:55:00Z
# 1      1934269f8f3a7a065318ec9a4e7984c0d9216332  2021-01-26T19:20:00Z
# 2      1934269f8f3a7a065318ec9a4e7984c0d9216332  2021-01-27T18:10:00Z
# 3      1934269f8f3a7a065318ec9a4e7984c0d9216332  2021-01-26T17:25:00Z
# 4      1934269f8f3a7a065318ec9a4e7984c0d9216332  2021-01-27T18:35:00Z
# ...                                         ...                   ...
# 11593  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-01-08T19:25:00Z
# 11594  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-01-08T17:15:00Z
# 11595  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-01-08T18:05:00Z
# 11596  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-01-08T16:15:00Z
# 11597  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-01-05T18:10:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               618                      650
# 1         heat          hold               649                      682
# 2         heat          hold               621                      682
# 3         heat          hold               622                      650
# 4         heat          hold               641                      682
# ...        ...           ...               ...                      ...
# 11593     heat          hold               682                      690
# 11594     heat          hold               680                      690
# 11595     heat          hold               688                      690
# 11596     heat          hold               683                      690
# 11597     heat          hold               681                      690
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          622            AK    Wasilla                    0
# 1                          682            AK    Wasilla                    0
# 2                          682            AK    Wasilla                    0
# 3                          622            AK    Wasilla                    0
# 4                          682            AK    Wasilla                    0
# ...                        ...           ...        ...                  ...
# 11593                      690            AK  Anchorage                   35
# 11594                      690            AK  Anchorage                   35
# 11595                      690            AK  Anchorage                   35
# 11596                      690            AK  Anchorage                   35
# 11597                      690            AK  Anchorage                   35
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 11593             False         False            False
# 11594             False         False            False
# 11595             False         False            False
# 11596             False         False            False
# 11597             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 11593                       Gas
# 11594                       Gas
# 11595                       Gas
# 11596                       Gas
# 11597                       Gas
#
# [5545 rows x 14 columns]

# %%
# Add year and month

jan_2021["Year"] = "2021"
jan_2021["Month"] = "Jan"

# %%
# Rename columns to label the aggregates

jan_2021 = jan_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jan_2021_ave = jan_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jan_2021_ave

# %%
# Export CSV file

jan_2021_ave.to_csv("data/day/AK/jan/jan_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/jan/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_jan = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/jan/" + file)
    AK_jan = pd.concat([AK_jan, df])
    
AK_jan
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   14a6f6af23d454bda9e5b09021f63af861c9ab83   Jan  2017     heat
# 1   18c482b133fba9f05f7edac61214d7cd1082ff1a   Jan  2017     heat
# 2   364d90d4305e64cf8a54685a3669aca9ba7667ed   Jan  2017     heat
# 3   6085162893ee544ece3ce04e242a68d7a8afe24d   Jan  2017     heat
# 4   6085162893ee544ece3ce04e242a68d7a8afe24d   Jan  2017     heat
# ..                                       ...   ...   ...      ...
# 17  bdc58f9e6d012d051afe58172dc008bebf29a356   Jan  2021     heat
# 18  d52d6af22f2bcad8215f8eec1a710dd00e190c7b   Jan  2021     heat
# 19  e189043abcdc363a66270079341e45b9be50fe29   Jan  2021     heat
# 20  e607ef283e0f21c02dcd7df409ee3e764d229b79   Jan  2021     heat
# 21  ea9f45a49e23bc298fc582a4ad9e006b53853255   Jan  2021     heat
#
#    CalendarEvent               City  Temperature_ctrl_ave  \
# 0           auto          Anchorage            642.000000
# 1           auto          Anchorage            642.055556
# 2           hold             Palmer            644.954545
# 3           auto  Russian Jack Park            629.122517
# 4           hold  Russian Jack Park            619.231492
# ..           ...                ...                   ...
# 17          hold   Huffman/O'Malley            702.300000
# 18          hold            Wasilla            528.027778
# 19          hold          Anchorage            651.500000
# 20          hold             Juneau            688.586387
# 21          hold             Bethel            705.153652
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    806.000000                   628.000000
# 1                    780.000000                   650.000000
# 2                    710.000000                   710.000000
# 3                    654.688742                   634.831126
# 4                    650.071680                   620.521739
# ..                          ...                          ...
# 17                   708.233333                   706.500000
# 18                   654.166667                   642.500000
# 19                   664.000000                   660.000000
# 20                   717.314136                   716.219895
# 21                   707.027708                   707.027708
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                  20.0             False         False            False
# 1                   5.0             False         False            False
# 2                   0.0             False         False            False
# 3                  20.0             False         False            False
# 4                  20.0             False         False            False
# ..                  ...               ...           ...              ...
# 17                 40.0             False         False            False
# 18                  5.0             False         False            False
# 19                 30.0             False         False            False
# 20                 50.0             False         False            False
# 21                 49.0             False         False            False
#
# [156 rows x 13 columns]

# %%
AK_jan.to_csv("Scraper_Output/State_Month_Day/AK/AK_jan.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## February

# %% [markdown]
# ### 2017 February Day

# %%
# Read in month csv for state
feb_2017 = pd.read_csv("../data_large/AK-day/2017-feb-day-AK.csv")

# feb_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
feb_2017.drop(feb_2017[feb_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
feb_2017.drop(feb_2017[feb_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
feb_2017.drop(feb_2017[feb_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
feb_2017.drop(feb_2017[feb_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

feb_2017
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-02-04T19:05:00Z     heat
# 1     364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-02-04T19:45:00Z     heat
# 2     364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-02-04T19:35:00Z     heat
# 3     364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-02-04T19:40:00Z     heat
# 4     364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-02-04T18:50:00Z     heat
# ...                                        ...                   ...      ...
# 6178  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-02-21T10:30:00Z     heat
# 6179  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-02-21T10:50:00Z     heat
# 6180  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-02-21T11:10:00Z     heat
# 6181  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-02-21T11:00:00Z     heat
# 6182  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-02-21T10:55:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               629                      650
# 1             hold               620                      650
# 2             hold               623                      650
# 3             hold               621                      650
# 4             hold               634                      650
# ...            ...               ...                      ...
# 6178          hold               700                      740
# 6179          hold               704                      740
# 6180          hold               708                      740
# 6181          hold               707                      740
# 6182          hold               705                      740
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         620            AK     Palmer                    0
# 1                         620            AK     Palmer                    0
# 2                         620            AK     Palmer                    0
# 3                         620            AK     Palmer                    0
# 4                         620            AK     Palmer                    0
# ...                       ...           ...        ...                  ...
# 6178                      740            AK  Anchorage                    0
# 6179                      740            AK  Anchorage                    0
# 6180                      740            AK  Anchorage                    0
# 6181                      740            AK  Anchorage                    0
# 6182                      740            AK  Anchorage                    0
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 6178             False         False            False
# 6179             False         False            False
# 6180             False         False            False
# 6181             False         False            False
# 6182             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 6178                       Gas
# 6179                       Gas
# 6180                       Gas
# 6181                       Gas
# 6182                       Gas
#
# [6165 rows x 14 columns]

# %%
# Add year and month

feb_2017["Year"] = "2017"
feb_2017["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2017 = feb_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
feb_2017_ave = feb_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2017_ave

# %%
# Export CSV file

feb_2017_ave.to_csv("data/day/AK/feb/feb_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 February Day

# %%
# Read in month csv for state
feb_2018 = pd.read_csv("../data_large/AK-day/2018-feb-day-AK.csv")

# feb_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
feb_2018.drop(feb_2018[feb_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
feb_2018.drop(feb_2018[feb_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
feb_2018.drop(feb_2018[feb_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
feb_2018.drop(feb_2018[feb_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

feb_2018
# Out:
#                                      Identifier             date_time  \
# 0      31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff  2018-02-09T07:05:00Z
# 1      dccf5d5620ccd2fb708408998d809914ea61e341  2018-02-18T08:20:00Z
# 2      31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff  2018-02-17T07:00:00Z
# 3      bd4080916565ff1b12e94f584799f455347b5815  2018-02-03T07:00:00Z
# 4      a799538555e2fb23d035a9aa0004122110571484  2018-02-21T16:15:00Z
# ...                                         ...                   ...
# 12581  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-02-01T19:50:00Z
# 12582  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-02-04T16:45:00Z
# 12583  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-02-04T18:25:00Z
# 12584  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-02-02T07:25:00Z
# 12585  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2018-02-01T17:45:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          auto               689                      721
# 1         heat          auto               676                      720
# 2         heat          hold               671                      750
# 3         heat          hold               752                      771
# 4         heat          auto               695                      780
# ...        ...           ...               ...                      ...
# 12581     heat          auto               741                      740
# 12582     heat          auto               742                      740
# 12583     heat          auto               741                      740
# 12584     heat          auto               734                      740
# 12585     heat          auto               733                      740
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          683            AK  Anchorage                   25
# 1                          617            AK  Anchorage                   45
# 2                          673            AK  Anchorage                   25
# 3                          749            AK     Palmer                    8
# 4                          693            AK  Anchorage                   40
# ...                        ...           ...        ...                  ...
# 12581                      740            AK    Wasilla                    5
# 12582                      740            AK    Wasilla                    5
# 12583                      740            AK    Wasilla                    5
# 12584                      740            AK    Wasilla                    5
# 12585                      740            AK    Wasilla                    5
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 12581             False         False            False
# 12582             False         False            False
# 12583             False         False            False
# 12584             False         False            False
# 12585             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 12581                       Gas
# 12582                       Gas
# 12583                       Gas
# 12584                       Gas
# 12585                       Gas
#
# [11025 rows x 14 columns]

# %%
# Add year and month

feb_2018["Year"] = "2018"
feb_2018["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2018 = feb_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
feb_2018_ave = feb_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2018_ave

# %%
# Export CSV file

feb_2018_ave.to_csv("data/day/AK/feb/feb_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 February Day

# %%
# Read in month csv for state
feb_2019 = pd.read_csv("../data_large/AK-day/2019-feb-day-AK.csv")

# feb_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
feb_2019.drop(feb_2019[feb_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
feb_2019.drop(feb_2019[feb_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
feb_2019.drop(feb_2019[feb_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
feb_2019.drop(feb_2019[feb_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

feb_2019
# Out:
#                                      Identifier             date_time  \
# 0      bdc58f9e6d012d051afe58172dc008bebf29a356  2019-02-03T08:25:00Z
# 2      de96ad05755fc1e2697dff5f2548474733554565  2019-02-17T07:20:00Z
# 11     de96ad05755fc1e2697dff5f2548474733554565  2019-02-24T08:25:00Z
# 13     a799538555e2fb23d035a9aa0004122110571484  2019-02-14T18:00:00Z
# 16     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2019-02-02T18:45:00Z
# ...                                         ...                   ...
# 14691  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-02-22T07:45:00Z
# 14692  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-02-23T19:15:00Z
# 14693  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-02-22T17:15:00Z
# 14694  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-02-21T15:45:00Z
# 14695  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-02-20T19:45:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               704                      728
# 2         heat          hold               678                      673
# 11        heat          hold               616                      695
# 13        heat          hold               649                      747
# 16        heat          hold               694                      726
# ...        ...           ...               ...                      ...
# 14691     heat          auto               733                      740
# 14692     heat          auto               732                      740
# 14693     heat          auto               741                      740
# 14694     heat          auto               728                      740
# 14695     heat          auto               731                      740
#
#        TemperatureExpectedHeat ProvinceState              City  \
# 0                          718            AK  Huffman/O'Malley
# 2                          646            AK         Anchorage
# 11                         605            AK         Anchorage
# 13                         677            AK         Anchorage
# 16                         693            AK             Homer
# ...                        ...           ...               ...
# 14691                      740            AK           Wasilla
# 14692                      740            AK           Wasilla
# 14693                      740            AK           Wasilla
# 14694                      740            AK           Wasilla
# 14695                      740            AK           Wasilla
#
#        Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                       40             False         False            False
# 2                       30             False         False            False
# 11                      30             False         False            False
# 13                      40             False         False            False
# 16                       0              True         False            False
# ...                    ...               ...           ...              ...
# 14691                    5             False         False            False
# 14692                    5             False         False            False
# 14693                    5             False         False            False
# 14694                    5             False         False            False
# 14695                    5             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 2                           Gas
# 11                          Gas
# 13                          Gas
# 16                          Gas
# ...                         ...
# 14691                       Gas
# 14692                       Gas
# 14693                       Gas
# 14694                       Gas
# 14695                       Gas
#
# [12295 rows x 14 columns]

# %%
# Add year and month

feb_2019["Year"] = "2019"
feb_2019["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2019 = feb_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
feb_2019_ave = feb_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2019_ave

# %%
# Export CSV file

feb_2019_ave.to_csv("data/day/AK/feb/feb_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 February Day

# %%
# Read in month csv for state
feb_2020 = pd.read_csv("../data_large/AK-day/2020-feb-day-AK.csv")

# feb_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
feb_2020.drop(feb_2020[feb_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
feb_2020.drop(feb_2020[feb_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
feb_2020.drop(feb_2020[feb_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
feb_2020.drop(feb_2020[feb_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

feb_2020
# Out:
#                                      Identifier             date_time  \
# 0      a46459975fa2d0e4a3736887ad3a0e3963c8feaf  2020-02-16T07:25:00Z
# 1      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-02-03T08:25:00Z
# 2      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-02-24T08:25:00Z
# 3      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-02-23T07:25:00Z
# 4      cd0c6dacc16ca9fd87a2258af6fe8291f9279be7  2020-02-02T08:25:00Z
# ...                                         ...                   ...
# 12875  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2020-02-02T07:30:00Z
# 12876  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2020-02-02T07:40:00Z
# 12877  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2020-02-02T07:35:00Z
# 12878  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2020-02-02T08:10:00Z
# 12879  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2020-02-02T08:25:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               701                      794
# 1         heat          hold               705                      764
# 2         heat          auto               698                      800
# 3         heat          hold               708                      694
# 4         heat          auto               708                      768
# ...        ...           ...               ...                      ...
# 12875     heat          auto               732                      720
# 12876     heat          auto               728                      720
# 12877     heat          auto               726                      720
# 12878     heat          auto               739                      720
# 12879     heat          auto               730                      720
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          671            AK     Juneau                   50
# 1                          674            AK  Anchorage                   15
# 2                          657            AK  Anchorage                   15
# 3                          688            AK  Anchorage                   15
# 4                          671            AK  Anchorage                   15
# ...                        ...           ...        ...                  ...
# 12875                      740            AK    Wasilla                    5
# 12876                      740            AK    Wasilla                    5
# 12877                      740            AK    Wasilla                    5
# 12878                      740            AK    Wasilla                    5
# 12879                      740            AK    Wasilla                    5
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 12875             False         False            False
# 12876             False         False            False
# 12877             False         False            False
# 12878             False         False            False
# 12879             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 12875                       Gas
# 12876                       Gas
# 12877                       Gas
# 12878                       Gas
# 12879                       Gas
#
# [5199 rows x 14 columns]

# %%
# Add year and month

feb_2020["Year"] = "2020"
feb_2020["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2020 = feb_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
feb_2020_ave = feb_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2020_ave

# %%
# Export CSV file

feb_2020_ave.to_csv("data/day/AK/feb/feb_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 February Day

# %%
# Read in month csv for state
feb_2021 = pd.read_csv("../data_large/AK-day/2021-feb-day-AK.csv")

# feb_2021

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
feb_2021.drop(feb_2021[feb_2021['TemperatureExpectedCool'] >= 850].index, inplace = True)
feb_2021.drop(feb_2021[feb_2021['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
feb_2021.drop(feb_2021[feb_2021['TemperatureExpectedCool'] <= 600].index, inplace = True)
feb_2021.drop(feb_2021[feb_2021['TemperatureExpectedHeat'] <= 600].index, inplace = True)

feb_2021
# Out:
#                                      Identifier             date_time  \
# 423    995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-02-24T16:45:00Z
# 424    995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-02-24T16:15:00Z
# 425    995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-02-24T16:10:00Z
# 426    995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-02-24T16:40:00Z
# 427    995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-02-24T16:55:00Z
# ...                                         ...                   ...
# 11873  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-02-12T16:50:00Z
# 11874  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-02-14T19:00:00Z
# 11875  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-02-10T17:55:00Z
# 11876  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-02-14T17:25:00Z
# 11877  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-02-10T19:35:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 423       heat          hold               627                      650
# 424       heat          hold               630                      650
# 425       heat          hold               633                      650
# 426       heat          hold               631                      650
# 427       heat          hold               624                      650
# ...        ...           ...               ...                      ...
# 11873     heat          hold               668                      740
# 11874     heat          hold               660                      740
# 11875     heat          hold               633                      740
# 11876     heat          hold               668                      740
# 11877     heat          hold               634                      740
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 423                        630            AK  Anchorage                   35
# 424                        630            AK  Anchorage                   35
# 425                        630            AK  Anchorage                   35
# 426                        630            AK  Anchorage                   35
# 427                        630            AK  Anchorage                   35
# ...                        ...           ...        ...                  ...
# 11873                      740            AK     Juneau                   50
# 11874                      740            AK     Juneau                   50
# 11875                      740            AK     Juneau                   50
# 11876                      740            AK     Juneau                   50
# 11877                      740            AK     Juneau                   50
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 423               False         False            False
# 424               False         False            False
# 425               False         False            False
# 426               False         False            False
# 427               False         False            False
# ...                 ...           ...              ...
# 11873             False         False            False
# 11874             False         False            False
# 11875             False         False            False
# 11876             False         False            False
# 11877             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 423                         Gas
# 424                         Gas
# 425                         Gas
# 426                         Gas
# 427                         Gas
# ...                         ...
# 11873                       Gas
# 11874                       Gas
# 11875                       Gas
# 11876                       Gas
# 11877                       Gas
#
# [5883 rows x 14 columns]

# %%
# Add year and month

feb_2021["Year"] = "2021"
feb_2021["Month"] = "feb"

# %%
# Rename columns to label the aggregates

feb_2021 = feb_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
feb_2021_ave = feb_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# feb_2021_ave

# %%
# Export CSV file

feb_2021_ave.to_csv("data/day/AK/feb/feb_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/feb/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_feb = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/feb/" + file)
    AK_feb = pd.concat([AK_feb, df])
    
AK_feb
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   feb  2017     heat
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f   feb  2017     heat
# 2   18c482b133fba9f05f7edac61214d7cd1082ff1a   feb  2017     heat
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed   feb  2017     heat
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed   feb  2017     heat
# ..                                       ...   ...   ...      ...
# 12  bdc58f9e6d012d051afe58172dc008bebf29a356   feb  2021     heat
# 13  cd0c6dacc16ca9fd87a2258af6fe8291f9279be7   feb  2021     heat
# 14  d52d6af22f2bcad8215f8eec1a710dd00e190c7b   feb  2021     heat
# 15  e607ef283e0f21c02dcd7df409ee3e764d229b79   feb  2021     heat
# 16  ea9f45a49e23bc298fc582a4ad9e006b53853255   feb  2021     heat
#
#    CalendarEvent              City  Temperature_ctrl_ave  \
# 0           auto             Homer            683.000000
# 1           hold             Homer            685.013699
# 2           auto         Anchorage            629.166667
# 3           auto            Palmer            593.161905
# 4           hold            Palmer            628.294118
# ..           ...               ...                   ...
# 12          hold  Huffman/O'Malley            693.233333
# 13          hold         Anchorage            676.222222
# 14          hold           Wasilla            620.636364
# 15          hold            Juneau            671.847737
# 16          hold            Bethel            708.334402
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    710.000000                   677.000000
# 1                    686.835616                   686.109589
# 2                    780.000000                   650.000000
# 3                    759.380952                   655.857143
# 4                    650.000000                   620.000000
# ..                          ...                          ...
# 12                   695.500000                   694.733333
# 13                   683.666667                   679.055556
# 14                   659.272727                   657.090909
# 15                   727.781893                   726.921811
# 16                   708.461538                   708.461538
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                   0.0              True         False            False
# 2                   5.0             False         False            False
# 3                   0.0             False         False            False
# 4                   0.0             False         False            False
# ..                  ...               ...           ...              ...
# 12                 40.0             False         False            False
# 13                 15.0             False         False            False
# 14                  5.0             False         False            False
# 15                 50.0             False         False            False
# 16                 49.0             False         False            False
#
# [139 rows x 13 columns]

# %%
AK_feb.to_csv("Scraper_Output/State_Month_Day/AK/AK_feb.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## March

# %% [markdown]
# ---
#
# ## April

# %% [markdown]
# ---
#
# ## May

# %% [markdown]
# ---
#
# ## June

# %% [markdown]
# ### 2017 June Day

# %%
# Read in month csv for state
jun_2017 = pd.read_csv("../data_large/AK-day/2017-jun-day-AK.csv")

# jun_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jun_2017.drop(jun_2017[jun_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
jun_2017.drop(jun_2017[jun_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jun_2017.drop(jun_2017[jun_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
jun_2017.drop(jun_2017[jun_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jun_2017
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-06-24T19:15:00Z     heat
# 1     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-06-24T19:00:00Z     heat
# 2     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-06-24T18:35:00Z     heat
# 3     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-06-24T19:05:00Z     heat
# 4     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-06-24T19:35:00Z     heat
# ...                                        ...                   ...      ...
# 5626  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-06-27T13:35:00Z     heat
# 5627  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-06-27T10:45:00Z     heat
# 5628  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-06-27T12:25:00Z     heat
# 5629  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-06-27T14:00:00Z     heat
# 5630  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-06-27T14:15:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               672                      650
# 1             hold               676                      650
# 2             hold               678                      650
# 3             hold               675                      650
# 4             hold               672                      650
# ...            ...               ...                      ...
# 5626          hold               717                      690
# 5627          hold               709                      690
# 5628          hold               691                      690
# 5629          hold               712                      690
# 5630          hold               716                      690
#
#       TemperatureExpectedHeat ProvinceState    City  Age_of_Home__years_  \
# 0                         630            AK   Homer                    0
# 1                         630            AK   Homer                    0
# 2                         630            AK   Homer                    0
# 3                         630            AK   Homer                    0
# 4                         630            AK   Homer                    0
# ...                       ...           ...     ...                  ...
# 5626                      690            AK  juneau                   27
# 5627                      690            AK  juneau                   27
# 5628                      690            AK  juneau                   27
# 5629                      690            AK  juneau                   27
# 5630                      690            AK  juneau                   27
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 True         False            False
# 1                 True         False            False
# 2                 True         False            False
# 3                 True         False            False
# 4                 True         False            False
# ...                ...           ...              ...
# 5626             False         False            False
# 5627             False         False            False
# 5628             False         False            False
# 5629             False         False            False
# 5630             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 5626                       Gas
# 5627                       Gas
# 5628                       Gas
# 5629                       Gas
# 5630                       Gas
#
# [5139 rows x 14 columns]

# %%
# Add year and month

jun_2017["Year"] = "2017"
jun_2017["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2017 = jun_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jun_2017_ave = jun_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2017_ave

# %%
# Export CSV file

jun_2017_ave.to_csv("data/day/AK/jun/jun_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 June Day

# %%
# Read in month csv for state
jun_2018 = pd.read_csv("../data_large/AK-day/2018-jun-day-AK.csv")

# jun_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jun_2018.drop(jun_2018[jun_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
jun_2018.drop(jun_2018[jun_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jun_2018.drop(jun_2018[jun_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
jun_2018.drop(jun_2018[jun_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jun_2018
# Out:
#                                      Identifier             date_time  \
# 1      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-06-29T17:10:00Z
# 2      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-06-13T18:15:00Z
# 3      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-06-23T19:20:00Z
# 4      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-06-16T18:55:00Z
# 5      0404ace1bcdf88d917bd860a04cd6c66fb51679f  2018-06-08T18:30:00Z
# ...                                         ...                   ...
# 10747  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2018-06-01T15:10:00Z
# 10748  b2926c336f48d0bdbcd5343bb68676b3a9364748  2018-06-16T17:05:00Z
# 10749  b2926c336f48d0bdbcd5343bb68676b3a9364748  2018-06-16T17:15:00Z
# 10750  b2926c336f48d0bdbcd5343bb68676b3a9364748  2018-06-16T17:10:00Z
# 10751  b2926c336f48d0bdbcd5343bb68676b3a9364748  2018-06-16T17:00:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 1         heat          hold               685                      690
# 2         heat          hold               657                      767
# 3         heat          hold               678                      720
# 4         heat          hold               677                      681
# 5         heat          hold               673                      663
# ...        ...           ...               ...                      ...
# 10747     heat          hold               653                      680
# 10748     heat          hold               698                      680
# 10749     heat          hold               690                      680
# 10750     heat          hold               693                      680
# 10751     heat          hold               702                      680
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 1                          678            AK      Homer                    0
# 2                          655            AK      Homer                    0
# 3                          672            AK      Homer                    0
# 4                          669            AK      Homer                    0
# 5                          633            AK      Homer                    0
# ...                        ...           ...        ...                  ...
# 10747                      680            AK  Anchorage                   35
# 10748                      680            AK      Healy                   10
# 10749                      680            AK      Healy                   10
# 10750                      680            AK      Healy                   10
# 10751                      680            AK      Healy                   10
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 1                  True         False            False
# 2                  True         False            False
# 3                  True         False            False
# 4                  True         False            False
# 5                  True         False            False
# ...                 ...           ...              ...
# 10747             False         False            False
# 10748             False         False            False
# 10749             False         False            False
# 10750             False         False            False
# 10751             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# 5                           Gas
# ...                         ...
# 10747                       Gas
# 10748                       Gas
# 10749                       Gas
# 10750                       Gas
# 10751                       Gas
#
# [9857 rows x 14 columns]

# %%
# Add year and month

jun_2018["Year"] = "2018"
jun_2018["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2018 = jun_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jun_2018_ave = jun_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2018_ave

# %%
# Export CSV file

jun_2018_ave.to_csv("data/day/AK/jun/jun_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 June Day

# %%
# Read in month csv for state
jun_2019 = pd.read_csv("../data_large/AK-day/2019-jun-day-AK.csv")

# jun_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jun_2019.drop(jun_2019[jun_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
jun_2019.drop(jun_2019[jun_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jun_2019.drop(jun_2019[jun_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
jun_2019.drop(jun_2019[jun_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jun_2019
# Out:
#                                     Identifier             date_time HvacMode  \
# 77    4cf15a20ba9d9a39d09e7b978b351754c3dfbe6e  2019-06-01T17:55:00Z     heat
# 78    4cf15a20ba9d9a39d09e7b978b351754c3dfbe6e  2019-06-01T16:30:00Z     heat
# 79    4cf15a20ba9d9a39d09e7b978b351754c3dfbe6e  2019-06-01T19:15:00Z     heat
# 80    4cf15a20ba9d9a39d09e7b978b351754c3dfbe6e  2019-06-01T16:35:00Z     heat
# 81    4cf15a20ba9d9a39d09e7b978b351754c3dfbe6e  2019-06-01T18:20:00Z     heat
# ...                                        ...                   ...      ...
# 7056  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2019-06-12T15:55:00Z     heat
# 7057  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2019-06-12T15:05:00Z     heat
# 7058  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2019-06-12T15:00:00Z     heat
# 7059  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2019-06-12T15:35:00Z     heat
# 7060  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2019-06-12T15:40:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 77            auto               615                      780
# 78            auto               616                      780
# 79            auto               618                      780
# 80            auto               616                      780
# 81            auto               615                      780
# ...            ...               ...                      ...
# 7056          hold               660                      690
# 7057          hold               668                      690
# 7058          hold               671                      690
# 7059          hold               662                      690
# 7060          hold               660                      690
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 77                        620            AK  Anchorage                   15
# 78                        620            AK  Anchorage                   15
# 79                        620            AK  Anchorage                   15
# 80                        620            AK  Anchorage                   15
# 81                        620            AK  Anchorage                   15
# ...                       ...           ...        ...                  ...
# 7056                      690            AK     juneau                   27
# 7057                      690            AK     juneau                   27
# 7058                      690            AK     juneau                   27
# 7059                      690            AK     juneau                   27
# 7060                      690            AK     juneau                   27
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 77                True         False            False
# 78                True         False            False
# 79                True         False            False
# 80                True         False            False
# 81                True         False            False
# ...                ...           ...              ...
# 7056             False         False            False
# 7057             False         False            False
# 7058             False         False            False
# 7059             False         False            False
# 7060             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 77                         Gas
# 78                         Gas
# 79                         Gas
# 80                         Gas
# 81                         Gas
# ...                        ...
# 7056                       Gas
# 7057                       Gas
# 7058                       Gas
# 7059                       Gas
# 7060                       Gas
#
# [5735 rows x 14 columns]

# %%
# Add year and month

jun_2019["Year"] = "2019"
jun_2019["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2019 = jun_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jun_2019_ave = jun_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2019_ave

# %%
# Export CSV file

jun_2019_ave.to_csv("data/day/AK/jun/jun_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 June Day

# %%
# Read in month csv for state
jun_2020 = pd.read_csv("../data_large/AK-day/2020-jun-day-AK.csv")

# jun_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jun_2020.drop(jun_2020[jun_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
jun_2020.drop(jun_2020[jun_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jun_2020.drop(jun_2020[jun_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
jun_2020.drop(jun_2020[jun_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jun_2020
# Out:
#                                      Identifier             date_time  \
# 470    1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-06-16T13:25:00Z
# 471    1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-06-16T13:35:00Z
# 472    1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-06-16T13:10:00Z
# 473    1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-06-16T13:55:00Z
# 474    1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-06-16T13:30:00Z
# ...                                         ...                   ...
# 10478  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-06-26T17:05:00Z
# 10479  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-06-25T19:45:00Z
# 10480  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-06-25T19:25:00Z
# 10481  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-06-26T16:45:00Z
# 10482  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-06-26T17:30:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 470       heat          hold               700                      650
# 471       heat          hold               698                      650
# 472       heat          hold               700                      650
# 473       heat          hold               697                      650
# 474       heat          hold               699                      650
# ...        ...           ...               ...                      ...
# 10478     heat          hold               732                      730
# 10479     heat          hold               714                      730
# 10480     heat          hold               721                      730
# 10481     heat          hold               724                      730
# 10482     heat          hold               731                      730
#
#        TemperatureExpectedHeat ProvinceState     City  Age_of_Home__years_  \
# 470                        620            AK  Wasilla                    0
# 471                        620            AK  Wasilla                    0
# 472                        620            AK  Wasilla                    0
# 473                        620            AK  Wasilla                    0
# 474                        620            AK  Wasilla                    0
# ...                        ...           ...      ...                  ...
# 10478                      730            AK   Juneau                   50
# 10479                      730            AK   Juneau                   50
# 10480                      730            AK   Juneau                   50
# 10481                      730            AK   Juneau                   50
# 10482                      730            AK   Juneau                   50
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 470               False         False            False
# 471               False         False            False
# 472               False         False            False
# 473               False         False            False
# 474               False         False            False
# ...                 ...           ...              ...
# 10478             False         False            False
# 10479             False         False            False
# 10480             False         False            False
# 10481             False         False            False
# 10482             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 470                         Gas
# 471                         Gas
# 472                         Gas
# 473                         Gas
# 474                         Gas
# ...                         ...
# 10478                       Gas
# 10479                       Gas
# 10480                       Gas
# 10481                       Gas
# 10482                       Gas
#
# [4016 rows x 14 columns]

# %%
# Add year and month

jun_2020["Year"] = "2020"
jun_2020["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2020 = jun_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jun_2020_ave = jun_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2020_ave

# %%
# Export CSV file

jun_2020_ave.to_csv("data/day/AK/jun/jun_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 June Day

# %%
# Read in month csv for state
jun_2021 = pd.read_csv("../data_large/AK-day/2021-jun-day-AK.csv")

# jun_2021

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jun_2021.drop(jun_2021[jun_2021['TemperatureExpectedCool'] >= 850].index, inplace = True)
jun_2021.drop(jun_2021[jun_2021['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jun_2021.drop(jun_2021[jun_2021['TemperatureExpectedCool'] <= 600].index, inplace = True)
jun_2021.drop(jun_2021[jun_2021['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jun_2021
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     bdc58f9e6d012d051afe58172dc008bebf29a356  2021-06-09T07:25:00Z     heat
# 1     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-06-11T17:50:00Z     heat
# 2     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-06-11T19:20:00Z     heat
# 3     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-06-11T19:05:00Z     heat
# 4     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-06-18T19:55:00Z     heat
# ...                                        ...                   ...      ...
# 7057  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-06-03T15:15:00Z     heat
# 7058  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-06-03T15:35:00Z     heat
# 7059  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-06-03T15:50:00Z     heat
# 7060  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-06-03T15:25:00Z     heat
# 7061  e607ef283e0f21c02dcd7df409ee3e764d229b79  2021-06-03T15:10:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               680                      696
# 1             hold               712                      715
# 2             hold               712                      715
# 3             hold               715                      715
# 4             hold               712                      715
# ...            ...               ...                      ...
# 7057          hold               693                      720
# 7058          hold               697                      720
# 7059          hold               700                      720
# 7060          hold               695                      720
# 7061          hold               692                      720
#
#       TemperatureExpectedHeat ProvinceState              City  \
# 0                         666            AK  Huffman/O'Malley
# 1                         715            AK         Anchorage
# 2                         715            AK         Anchorage
# 3                         715            AK         Anchorage
# 4                         715            AK         Anchorage
# ...                       ...           ...               ...
# 7057                      720            AK            Juneau
# 7058                      720            AK            Juneau
# 7059                      720            AK            Juneau
# 7060                      720            AK            Juneau
# 7061                      720            AK            Juneau
#
#       Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                      40             False         False            False
# 1                      20             False         False            False
# 2                      20             False         False            False
# 3                      20             False         False            False
# 4                      20             False         False            False
# ...                   ...               ...           ...              ...
# 7057                   50             False         False            False
# 7058                   50             False         False            False
# 7059                   50             False         False            False
# 7060                   50             False         False            False
# 7061                   50             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 7057                       Gas
# 7058                       Gas
# 7059                       Gas
# 7060                       Gas
# 7061                       Gas
#
# [5868 rows x 14 columns]

# %%
# Add year and month

jun_2021["Year"] = "2021"
jun_2021["Month"] = "jun"

# %%
# Rename columns to label the aggregates

jun_2021 = jun_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jun_2021_ave = jun_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jun_2021_ave

# %%
# Export CSV file

jun_2021_ave.to_csv("data/day/AK/jun/jun_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/jun/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_jun = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/jun/" + file)
    AK_jun = pd.concat([AK_jun, df])
    
AK_jun
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jun  2017     heat
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jun  2017     heat
# 2   1544f3165814ae017488964fc29ae302bba75bb7   jun  2017     heat
# 3   1544f3165814ae017488964fc29ae302bba75bb7   jun  2017     heat
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed   jun  2017     heat
# ..                                       ...   ...   ...      ...
# 10  995e1c96a74ee2cb3509db751eb6310b63e5aa94   jun  2021     heat
# 11  bdc58f9e6d012d051afe58172dc008bebf29a356   jun  2021     heat
# 12  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jun  2021     heat
# 13  e189043abcdc363a66270079341e45b9be50fe29   jun  2021     heat
# 14  e607ef283e0f21c02dcd7df409ee3e764d229b79   jun  2021     heat
#
#    CalendarEvent              City  Temperature_ctrl_ave  \
# 0           auto             Homer            647.000000
# 1           hold             Homer            668.244094
# 2           auto            juneau            692.543478
# 3           hold            juneau            693.415094
# 4           auto            Palmer            705.428571
# ..           ...               ...                   ...
# 10          hold         Anchorage            680.368490
# 11          hold  Huffman/O'Malley            679.000000
# 12          hold            juneau            702.277778
# 13          hold         Anchorage            650.250000
# 14          hold            Juneau            700.432432
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    747.000000                   637.000000
# 1                    667.244094                   660.929134
# 2                    681.369565                   680.652174
# 3                    689.490566                   688.471698
# 4                    736.285714                   710.571429
# ..                          ...                          ...
# 10                   672.600260                   656.790365
# 11                   674.333333                   669.333333
# 12                   653.194444                   653.166667
# 13                   780.250000                   649.062500
# 14                   741.648649                   738.351351
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                   0.0              True         False            False
# 2                  27.0             False         False            False
# 3                  27.0             False         False            False
# 4                   0.0             False         False            False
# ..                  ...               ...           ...              ...
# 10                 35.0             False         False            False
# 11                 40.0             False         False            False
# 12                 27.0             False         False            False
# 13                 30.0             False         False            False
# 14                 50.0             False         False            False
#
# [82 rows x 13 columns]

# %%
AK_jun.to_csv("Scraper_Output/State_Month_Day/AK/AK_jun.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## July

# %% [markdown]
# ### 2017 July Day

# %%
# Read in month csv for state
jul_2017 = pd.read_csv("../data_large/AK-day/2017-jul-day-AK.csv")

# jul_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jul_2017.drop(jul_2017[jul_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
jul_2017.drop(jul_2017[jul_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jul_2017.drop(jul_2017[jul_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
jul_2017.drop(jul_2017[jul_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jul_2017
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-07-26T18:05:00Z     heat
# 1     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-07-29T17:20:00Z     heat
# 2     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-07-13T17:50:00Z     heat
# 3     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-07-17T15:40:00Z     heat
# 4     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-07-09T19:00:00Z     heat
# ...                                        ...                   ...      ...
# 6184  364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-07-04T15:50:00Z     heat
# 6185  364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-07-04T15:45:00Z     heat
# 6186  364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-07-04T15:55:00Z     heat
# 6187  364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-07-04T15:50:00Z     heat
# 6188  364d90d4305e64cf8a54685a3669aca9ba7667ed  2017-07-04T15:55:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               671                      741
# 1             hold               673                      752
# 2             hold               709                      702
# 3             hold               656                      714
# 4             hold               676                      720
# ...            ...               ...                      ...
# 6184          auto               704                      740
# 6185          auto               698                      740
# 6186          auto               708                      740
# 6187          auto               704                      740
# 6188          auto               708                      740
#
#       TemperatureExpectedHeat ProvinceState    City  Age_of_Home__years_  \
# 0                         657            AK   Homer                    0
# 1                         655            AK   Homer                    0
# 2                         638            AK   Homer                    0
# 3                         655            AK   Homer                    0
# 4                         668            AK   Homer                    0
# ...                       ...           ...     ...                  ...
# 6184                      740            AK  Palmer                    0
# 6185                      740            AK  Palmer                    0
# 6186                      740            AK  Palmer                    0
# 6187                      740            AK  Palmer                    0
# 6188                      740            AK  Palmer                    0
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 True         False            False
# 1                 True         False            False
# 2                 True         False            False
# 3                 True         False            False
# 4                 True         False            False
# ...                ...           ...              ...
# 6184             False         False            False
# 6185             False         False            False
# 6186             False         False            False
# 6187             False         False            False
# 6188             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 6184                       Gas
# 6185                       Gas
# 6186                       Gas
# 6187                       Gas
# 6188                       Gas
#
# [5319 rows x 14 columns]

# %%
# Add year and month

jul_2017["Year"] = "2017"
jul_2017["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2017 = jul_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jul_2017_ave = jul_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2017_ave

# %%
# Export CSV file

jul_2017_ave.to_csv("data/day/AK/jul/jul_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 July Day

# %%
# Read in month csv for state
jul_2018 = pd.read_csv("../data_large/AK-day/2018-jul-day-AK.csv")

# jul_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jul_2018.drop(jul_2018[jul_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
jul_2018.drop(jul_2018[jul_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jul_2018.drop(jul_2018[jul_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
jul_2018.drop(jul_2018[jul_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jul_2018
# Out:
#                                     Identifier             date_time HvacMode  \
# 168   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-07-14T18:30:00Z     heat
# 169   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-07-28T16:15:00Z     heat
# 170   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-07-29T17:10:00Z     heat
# 171   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-07-17T14:50:00Z     heat
# 172   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-07-26T14:55:00Z     heat
# ...                                        ...                   ...      ...
# 9840  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2018-07-30T11:50:00Z     heat
# 9841  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2018-07-30T11:55:00Z     heat
# 9842  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2018-07-29T11:45:00Z     heat
# 9843  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2018-07-13T10:25:00Z     heat
# 9844  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2018-07-10T11:40:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 168           hold               634                      650
# 169           hold               663                      650
# 170           hold               667                      650
# 171           hold               655                      650
# 172           hold               666                      650
# ...            ...               ...                      ...
# 9840          auto               683                      720
# 9841          auto               683                      720
# 9842          auto               684                      720
# 9843          auto               674                      690
# 9844          hold               682                      690
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 168                       610            AK  Anchorage                    0
# 169                       610            AK  Anchorage                    0
# 170                       610            AK  Anchorage                    0
# 171                       610            AK  Anchorage                    0
# 172                       610            AK  Anchorage                    0
# ...                       ...           ...        ...                  ...
# 9840                      690            AK     juneau                   27
# 9841                      690            AK     juneau                   27
# 9842                      690            AK     juneau                   27
# 9843                      690            AK     juneau                   27
# 9844                      690            AK     juneau                   27
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 168              False         False            False
# 169              False         False            False
# 170              False         False            False
# 171              False         False            False
# 172              False         False            False
# ...                ...           ...              ...
# 9840             False         False            False
# 9841             False         False            False
# 9842             False         False            False
# 9843             False         False            False
# 9844             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 168                        Gas
# 169                        Gas
# 170                        Gas
# 171                        Gas
# 172                        Gas
# ...                        ...
# 9840                       Gas
# 9841                       Gas
# 9842                       Gas
# 9843                       Gas
# 9844                       Gas
#
# [9199 rows x 14 columns]

# %%
# Add year and month

jul_2018["Year"] = "2018"
jul_2018["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2018 = jul_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jul_2018_ave = jul_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2018_ave

# %%
# Export CSV file

jul_2018_ave.to_csv("data/day/AK/jul/jul_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 July Day

# %%
# Read in month csv for state
jul_2019 = pd.read_csv("../data_large/AK-day/2019-jul-day-AK.csv")

# jul_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jul_2019.drop(jul_2019[jul_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
jul_2019.drop(jul_2019[jul_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jul_2019.drop(jul_2019[jul_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
jul_2019.drop(jul_2019[jul_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jul_2019
# Out:
#                                      Identifier             date_time  \
# 66     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2019-07-28T19:25:00Z
# 67     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2019-07-25T17:05:00Z
# 68     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2019-07-28T18:00:00Z
# 69     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2019-07-11T17:45:00Z
# 70     68a1a0651c36267368651a504b1a50737727928a  2019-07-16T17:15:00Z
# ...                                         ...                   ...
# 10286  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-07-29T19:05:00Z
# 10287  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-07-20T15:05:00Z
# 10288  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-07-31T15:00:00Z
# 10289  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-07-12T16:25:00Z
# 10290  d52d6af22f2bcad8215f8eec1a710dd00e190c7b  2019-07-07T18:45:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 66        heat          hold               678                      687
# 67        heat          hold               702                      732
# 68        heat          hold               658                      689
# 69        heat          hold               698                      792
# 70        heat          auto               697                      792
# ...        ...           ...               ...                      ...
# 10286     heat          auto               684                      710
# 10287     heat          auto               727                      710
# 10288     heat          auto               675                      710
# 10289     heat          auto               697                      710
# 10290     heat          auto               732                      710
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 66                         676            AK  Anchorage                   20
# 67                         688            AK  Anchorage                   20
# 68                         678            AK  Anchorage                   20
# 69                         627            AK  Anchorage                   20
# 70                         656            AK  Anchorage                   40
# ...                        ...           ...        ...                  ...
# 10286                      680            AK    Wasilla                    5
# 10287                      680            AK    Wasilla                    5
# 10288                      680            AK    Wasilla                    5
# 10289                      680            AK    Wasilla                    5
# 10290                      680            AK    Wasilla                    5
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 66                False         False            False
# 67                False         False            False
# 68                False         False            False
# 69                False         False            False
# 70                False         False            False
# ...                 ...           ...              ...
# 10286             False         False            False
# 10287             False         False            False
# 10288             False         False            False
# 10289             False         False            False
# 10290             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 66                          Gas
# 67                          Gas
# 68                          Gas
# 69                          Gas
# 70                          Gas
# ...                         ...
# 10286                       Gas
# 10287                       Gas
# 10288                       Gas
# 10289                       Gas
# 10290                       Gas
#
# [8784 rows x 14 columns]

# %%
# Add year and month

jul_2019["Year"] = "2019"
jul_2019["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2019 = jul_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jul_2019_ave = jul_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2019_ave

# %%
# Export CSV file

jul_2019_ave.to_csv("data/day/AK/jul/jul_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 July Day

# %%
# Read in month csv for state
jul_2020 = pd.read_csv("../data_large/AK-day/2020-jul-day-AK.csv")

# jul_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jul_2020.drop(jul_2020[jul_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
jul_2020.drop(jul_2020[jul_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jul_2020.drop(jul_2020[jul_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
jul_2020.drop(jul_2020[jul_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

jul_2020
# Out:
#                                     Identifier             date_time HvacMode  \
# 48    0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-07-03T16:50:00Z     heat
# 49    0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-07-06T19:10:00Z     heat
# 50    a988392d2cf43e32b9b458db27ccb5cc50f335ac  2020-07-09T18:35:00Z     heat
# 51    a988392d2cf43e32b9b458db27ccb5cc50f335ac  2020-07-09T18:45:00Z     heat
# 52    a988392d2cf43e32b9b458db27ccb5cc50f335ac  2020-07-09T18:30:00Z     heat
# ...                                        ...                   ...      ...
# 5157  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-07-14T19:30:00Z     heat
# 5158  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-07-21T17:20:00Z     heat
# 5159  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-07-07T16:05:00Z     heat
# 5160  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-07-08T18:40:00Z     heat
# 5161  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2020-07-09T16:05:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 48            hold               698                      752
# 49            hold               704                      795
# 50            auto               638                      650
# 51            auto               636                      650
# 52            auto               634                      650
# ...            ...               ...                      ...
# 5157          hold               730                      740
# 5158          hold               732                      740
# 5159          hold               738                      740
# 5160          hold               742                      740
# 5161          hold               728                      740
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 48                        620            AK  Anchorage                   20
# 49                        630            AK  Anchorage                   20
# 50                        640            AK  Anchorage                   30
# 51                        640            AK  Anchorage                   30
# 52                        640            AK  Anchorage                   30
# ...                       ...           ...        ...                  ...
# 5157                      740            AK  Anchorage                   35
# 5158                      740            AK  Anchorage                   35
# 5159                      740            AK  Anchorage                   35
# 5160                      740            AK  Anchorage                   35
# 5161                      740            AK  Anchorage                   35
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 48               False         False            False
# 49               False         False            False
# 50               False         False            False
# 51               False         False            False
# 52               False         False            False
# ...                ...           ...              ...
# 5157             False         False            False
# 5158             False         False            False
# 5159             False         False            False
# 5160             False         False            False
# 5161             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 48                         Gas
# 49                         Gas
# 50                         Gas
# 51                         Gas
# 52                         Gas
# ...                        ...
# 5157                       Gas
# 5158                       Gas
# 5159                       Gas
# 5160                       Gas
# 5161                       Gas
#
# [3689 rows x 14 columns]

# %%
# Add year and month

jul_2020["Year"] = "2020"
jul_2020["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2020 = jul_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jul_2020_ave = jul_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2020_ave

# %%
# Export CSV file

jul_2020_ave.to_csv("data/day/AK/jul/jul_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2021 July Day

# %%
# Read in month csv for state
jul_2021 = pd.read_csv("../data_large/AK-day/2021-jul-day-AK.csv")

# jul_2021

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
jul_2021.drop(jul_2021[jul_2021['TemperatureExpectedCool'] >= 850].index, inplace = True)
jul_2021.drop(jul_2021[jul_2021['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
jul_2021.drop(jul_2021[jul_2021['TemperatureExpectedHeat'] <= 600].index, inplace = True)
jul_2021.drop(jul_2021[jul_2021['TemperatureExpectedCool'] <= 600].index, inplace = True)

jul_2021
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-07-28T19:15:00Z     heat
# 1     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-07-28T18:00:00Z     heat
# 2     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-07-28T19:20:00Z     heat
# 3     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-07-23T17:50:00Z     heat
# 4     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2021-07-06T19:45:00Z     heat
# ...                                        ...                   ...      ...
# 6138  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-07-28T19:05:00Z     heat
# 6139  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-07-28T17:10:00Z     heat
# 6140  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-07-28T19:10:00Z     heat
# 6141  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-07-28T18:15:00Z     heat
# 6142  995e1c96a74ee2cb3509db751eb6310b63e5aa94  2021-07-27T17:15:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               716                      715
# 1             hold               710                      715
# 2             hold               715                      715
# 3             hold               713                      715
# 4             hold               697                      715
# ...            ...               ...                      ...
# 6138          hold               683                      690
# 6139          hold               685                      690
# 6140          hold               682                      690
# 6141          hold               686                      690
# 6142          hold               684                      690
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         715            AK  Anchorage                   20
# 1                         715            AK  Anchorage                   20
# 2                         715            AK  Anchorage                   20
# 3                         715            AK  Anchorage                   20
# 4                         715            AK  Anchorage                   20
# ...                       ...           ...        ...                  ...
# 6138                      690            AK  Anchorage                   35
# 6139                      690            AK  Anchorage                   35
# 6140                      690            AK  Anchorage                   35
# 6141                      690            AK  Anchorage                   35
# 6142                      690            AK  Anchorage                   35
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 6138             False         False            False
# 6139             False         False            False
# 6140             False         False            False
# 6141             False         False            False
# 6142             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 6138                       Gas
# 6139                       Gas
# 6140                       Gas
# 6141                       Gas
# 6142                       Gas
#
# [5645 rows x 14 columns]

# %%
# Add year and month

jul_2021["Year"] = "2021"
jul_2021["Month"] = "jul"

# %%
# Rename columns to label the aggregates

jul_2021 = jul_2021.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
jul_2021_ave = jul_2021.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# jul_2021_ave

# %%
# Export CSV file

jul_2021_ave.to_csv("data/day/AK/jul/jul_2021_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/jul/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_jul = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/jul/" + file)
    AK_jul = pd.concat([AK_jul, df])
    
AK_jul
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jul  2017     heat
# 1   1544f3165814ae017488964fc29ae302bba75bb7   jul  2017     heat
# 2   364d90d4305e64cf8a54685a3669aca9ba7667ed   jul  2017     heat
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed   jul  2017     heat
# 4   bdad2c2f85c6d00c7ceea6df8246135cb8da01ae   jul  2017     heat
# 5   be4f2a63b7719c2a69aa285e8a38038c29df8fa6   jul  2017     heat
# 6   be4f2a63b7719c2a69aa285e8a38038c29df8fa6   jul  2017     heat
# 7   d52d6af22f2bcad8215f8eec1a710dd00e190c7b   jul  2017     heat
# 8   df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jul  2017     heat
# 9   fda1f67e8423ed49933c45617ee96aef3bae04ba   jul  2017     heat
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jul  2018     heat
# 1   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2018     heat
# 2   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2018     heat
# 3   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   jul  2018     heat
# 4   3c569abab42071063670722a0b326b0da8738423   jul  2018     heat
# 5   3c569abab42071063670722a0b326b0da8738423   jul  2018     heat
# 6   7f8d7869602b0becdb1f67e15d7796602e5cae7d   jul  2018     heat
# 7   7f8d7869602b0becdb1f67e15d7796602e5cae7d   jul  2018     heat
# 8   995e1c96a74ee2cb3509db751eb6310b63e5aa94   jul  2018     heat
# 9   bd4080916565ff1b12e94f584799f455347b5815   jul  2018     heat
# 10  bd4080916565ff1b12e94f584799f455347b5815   jul  2018     heat
# 11  be4f2a63b7719c2a69aa285e8a38038c29df8fa6   jul  2018     heat
# 12  c810efa572eb24b685d4ea14eb98d7f79cac0bd3   jul  2018     heat
# 13  d52d6af22f2bcad8215f8eec1a710dd00e190c7b   jul  2018     heat
# 14  d52d6af22f2bcad8215f8eec1a710dd00e190c7b   jul  2018     heat
# 15  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jul  2018     heat
# 16  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jul  2018     heat
# 17  e189043abcdc363a66270079341e45b9be50fe29   jul  2018     heat
# 18  e189043abcdc363a66270079341e45b9be50fe29   jul  2018     heat
# 19  fda1f67e8423ed49933c45617ee96aef3bae04ba   jul  2018     heat
# 0   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2019     heat
# 1   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2019     heat
# 2   2678ac2aec9a1f53acad226c2c437efd25ea7dc8   jul  2019     heat
# 3   68a1a0651c36267368651a504b1a50737727928a   jul  2019     heat
# 4   995e1c96a74ee2cb3509db751eb6310b63e5aa94   jul  2019     heat
# 5   d52d6af22f2bcad8215f8eec1a710dd00e190c7b   jul  2019     heat
# 6   fda1f67e8423ed49933c45617ee96aef3bae04ba   jul  2019     heat
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jul  2020     heat
# 1   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2020     heat
# 2   1544f3165814ae017488964fc29ae302bba75bb7   jul  2020     heat
# 3   1544f3165814ae017488964fc29ae302bba75bb7   jul  2020     heat
# 4   2678ac2aec9a1f53acad226c2c437efd25ea7dc8   jul  2020     heat
# 5   31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff   jul  2020     heat
# 6   995e1c96a74ee2cb3509db751eb6310b63e5aa94   jul  2020     heat
# 7   a988392d2cf43e32b9b458db27ccb5cc50f335ac   jul  2020     heat
# 8   de96ad05755fc1e2697dff5f2548474733554565   jul  2020     heat
# 9   de96ad05755fc1e2697dff5f2548474733554565   jul  2020     heat
# 10  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jul  2020     heat
# 11  e607ef283e0f21c02dcd7df409ee3e764d229b79   jul  2020     heat
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   jul  2021     heat
# 1   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   jul  2021     heat
# 2   2678ac2aec9a1f53acad226c2c437efd25ea7dc8   jul  2021     heat
# 3   3c569abab42071063670722a0b326b0da8738423   jul  2021     heat
# 4   55fb88f70abf5cbe75ab0c20eb02b0ed8f36f0da   jul  2021     heat
# 5   81a7bd30ff87a8f606e1378fe9117abbded76a9c   jul  2021     heat
# 6   995e1c96a74ee2cb3509db751eb6310b63e5aa94   jul  2021     heat
# 7   a988392d2cf43e32b9b458db27ccb5cc50f335ac   jul  2021     heat
# 8   df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jul  2021     heat
#
#    CalendarEvent              City  Temperature_ctrl_ave  \
# 0           hold             Homer            675.649123
# 1           hold            juneau            694.796296
# 2           auto            Palmer            689.735294
# 3           hold            Palmer            694.370968
# 4           auto         Anchorage            693.472906
# 5           auto         Anchorage            698.142857
# 6           hold         Anchorage            739.740741
# 7           auto           Wasilla            692.985644
# 8           hold            juneau            687.289157
# 9           hold           Wasilla            679.433362
# 0           hold             Homer            686.369231
# 1           auto         Anchorage            676.666667
# 2           hold         Anchorage            676.759494
# 3           hold         Anchorage            666.676717
# 4           auto         Anchorage            688.500000
# 5           hold         Anchorage            700.679688
# 6           auto         Anchorage            728.990741
# 7           hold         Anchorage            702.978836
# 8           hold         Anchorage            703.544986
# 9           auto            Palmer            757.000000
# 10          hold            Palmer            729.852941
# 11          hold         Anchorage            700.444444
# 12          hold        North Pole            747.619231
# 13          auto           Wasilla            708.926142
# 14          hold           Wasilla            673.522491
# 15          auto            juneau            681.459722
# 16          hold            juneau            691.228571
# 17          auto         Anchorage            712.729730
# 18          hold         Anchorage            676.900000
# 19          hold           Wasilla            689.578223
# 0           auto         Anchorage            675.617647
# 1           hold         Anchorage            699.791045
# 2           auto            Bethel            718.366209
# 3           auto         Anchorage            709.500000
# 4           hold         Anchorage            733.049051
# 5           auto           Wasilla            704.110228
# 6           hold           Wasilla            681.179004
# 0           hold             Homer            718.741935
# 1           hold         Anchorage            710.635371
# 2           auto            juneau            710.111111
# 3           hold            juneau            671.973333
# 4           auto            Bethel            704.382051
# 5           hold         Anchorage            681.071429
# 6           hold         Anchorage            719.092739
# 7           auto         Anchorage            630.875000
# 8           auto         Anchorage            654.750000
# 9           hold         Anchorage            666.333333
# 10          auto            juneau            688.884409
# 11          hold            Juneau            713.258065
# 0           hold             Homer            673.083333
# 1           hold         Anchorage            709.654054
# 2           hold            Bethel            704.505405
# 3           hold         Anchorage            697.146667
# 4           hold  Huffman/O'Malley            705.408805
# 5           hold           Chugiak            688.009583
# 6           hold         Anchorage            680.675932
# 7           hold         Anchorage            638.625000
# 8           hold            juneau            680.406130
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    673.706140                   668.429825
# 1                    690.000000                   690.000000
# 2                    705.000000                   704.411765
# 3                    659.693548                   652.322581
# 4                    780.083744                   619.871921
# 5                    700.000000                   700.000000
# 6                    740.000000                   740.000000
# 7                    650.000000                   650.000000
# 8                    682.771084                   682.771084
# 9                    652.528310                   644.569251
# 0                    659.753846                   649.784615
# 1                    680.000000                   680.000000
# 2                    667.585895                   667.585895
# 3                    650.745394                   611.740369
# 4                    779.541667                   690.222222
# 5                    704.187500                   703.515625
# 6                    717.777778                   682.185185
# 7                    655.079365                   653.211640
# 8                    687.438395                   687.438395
# 9                    710.000000                   710.000000
# 10                   724.411765                   724.411765
# 11                   750.000000                   750.000000
# 12                   650.000000                   630.000000
# 13                   658.223698                   676.781084
# 14                   655.259516                   655.259516
# 15                   695.833333                   661.250000
# 16                   687.142857                   687.142857
# 17                   780.324324                   648.702703
# 18                   677.340000                   675.740000
# 19                   653.227159                   643.533792
# 0                    680.000000                   680.000000
# 1                    706.865672                   704.320896
# 2                    660.000000                   660.000000
# 3                    795.500000                   649.000000
# 4                    661.459586                   661.429729
# 5                    710.000000                   680.000000
# 6                    650.000000                   640.000000
# 0                    710.000000                   710.000000
# 1                    717.746725                   716.089520
# 2                    670.000000                   670.000000
# 3                    670.000000                   670.000000
# 4                    660.000000                   660.000000
# 5                    670.000000                   670.000000
# 6                    714.491014                   714.491014
# 7                    655.625000                   637.375000
# 8                    680.000000                   680.000000
# 9                    658.000000                   658.000000
# 10                   720.000000                   690.094086
# 11                   690.000000                   690.000000
# 0                    650.000000                   630.000000
# 1                    717.508108                   716.832432
# 2                    650.000000                   647.000000
# 3                    701.386667                   699.906667
# 4                    700.000000                   700.000000
# 5                    650.000000                   640.000000
# 6                    666.468475                   655.922712
# 7                    650.000000                   640.000000
# 8                    650.000000                   650.000000
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                  27.0             False         False            False
# 2                   0.0             False         False            False
# 3                   0.0             False         False            False
# 4                  40.0             False         False            False
# 5                   0.0             False         False            False
# 6                   0.0             False         False            False
# 7                   5.0             False         False            False
# 8                  27.0             False         False            False
# 9                   0.0             False         False            False
# 0                   0.0              True         False            False
# 1                  20.0             False         False            False
# 2                  20.0             False         False            False
# 3                   0.0             False         False            False
# 4                  25.0             False         False            False
# 5                  25.0             False         False            False
# 6                  15.0              True         False            False
# 7                  15.0              True         False            False
# 8                  35.0             False         False            False
# 9                   8.0             False         False            False
# 10                  8.0             False         False            False
# 11                  0.0             False         False            False
# 12                  0.0             False         False            False
# 13                  5.0             False         False            False
# 14                  5.0             False         False            False
# 15                 27.0             False         False            False
# 16                 27.0             False         False            False
# 17                 30.0             False         False            False
# 18                 30.0             False         False            False
# 19                  0.0             False         False            False
# 0                  20.0             False         False            False
# 1                  20.0             False         False            False
# 2                  10.0             False         False            False
# 3                  40.0             False         False            False
# 4                  35.0             False         False            False
# 5                   5.0             False         False            False
# 6                   0.0             False         False            False
# 0                   0.0              True         False            False
# 1                  20.0             False         False            False
# 2                  27.0             False         False            False
# 3                  27.0             False         False            False
# 4                  10.0             False         False            False
# 5                  25.0             False         False            False
# 6                  35.0             False         False            False
# 7                  30.0             False         False            False
# 8                  30.0             False         False            False
# 9                  30.0             False         False            False
# 10                 27.0             False         False            False
# 11                 50.0             False         False            False
# 0                   0.0              True         False            False
# 1                  20.0             False         False            False
# 2                  10.0             False         False            False
# 3                  25.0             False         False            False
# 4                  40.0             False         False            False
# 5                  10.0              True         False            False
# 6                  35.0             False         False            False
# 7                  30.0             False         False            False
# 8                  27.0             False         False            False

# %%
AK_jul.to_csv("Scraper_Output/State_Month_Day/AK/AK_jul.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## August

# %% [markdown]
# ### 2017 August Day

# %%
# Read in month csv for state
aug_2017 = pd.read_csv("../data_large/AK-day/2017-aug-day-AK.csv")

# aug_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
aug_2017.drop(aug_2017[aug_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
aug_2017.drop(aug_2017[aug_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
aug_2017.drop(aug_2017[aug_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
aug_2017.drop(aug_2017[aug_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

aug_2017
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-06T07:00:00Z     heat
# 1     31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff  2017-08-04T15:40:00Z     heat
# 2     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-21T08:40:00Z     heat
# 3     be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-05T19:00:00Z     heat
# 4     0404ace1bcdf88d917bd860a04cd6c66fb51679f  2017-08-30T18:05:00Z     heat
# ...                                        ...                   ...      ...
# 6018  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-01T07:40:00Z     heat
# 6019  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-01T16:25:00Z     heat
# 6020  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-01T15:40:00Z     heat
# 6021  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-01T07:10:00Z     heat
# 6022  be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-08-01T16:20:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               729                      773
# 1             auto               693                      712
# 2             auto               721                      726
# 3             hold               716                      721
# 4             hold               671                      775
# ...            ...               ...                      ...
# 6018          hold               733                      740
# 6019          hold               738                      740
# 6020          hold               734                      740
# 6021          hold               736                      740
# 6022          hold               739                      740
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         695            AK  Anchorage                    0
# 1                         692            AK  Anchorage                   25
# 2                         718            AK  Anchorage                    0
# 3                         659            AK  Anchorage                    0
# 4                         651            AK      Homer                    0
# ...                       ...           ...        ...                  ...
# 6018                      740            AK  Anchorage                    0
# 6019                      740            AK  Anchorage                    0
# 6020                      740            AK  Anchorage                    0
# 6021                      740            AK  Anchorage                    0
# 6022                      740            AK  Anchorage                    0
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                 True         False            False
# ...                ...           ...              ...
# 6018             False         False            False
# 6019             False         False            False
# 6020             False         False            False
# 6021             False         False            False
# 6022             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 6018                       Gas
# 6019                       Gas
# 6020                       Gas
# 6021                       Gas
# 6022                       Gas
#
# [5752 rows x 14 columns]

# %%
# Add year and month

aug_2017["Year"] = "2017"
aug_2017["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2017 = aug_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
aug_2017_ave = aug_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2017_ave

# %%
# Export CSV file

aug_2017_ave.to_csv("data/day/AK/aug/aug_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 August Day

# %%
# Read in month csv for state
aug_2018 = pd.read_csv("../data_large/AK-day/2018-aug-day-AK.csv")

# aug_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
aug_2018.drop(aug_2018[aug_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
aug_2018.drop(aug_2018[aug_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
aug_2018.drop(aug_2018[aug_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
aug_2018.drop(aug_2018[aug_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

aug_2018
# Out:
#                                      Identifier             date_time  \
# 0      2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-08-05T19:15:00Z
# 1      2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-08-04T16:00:00Z
# 2      2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-08-05T16:40:00Z
# 3      2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-08-05T16:45:00Z
# 4      2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a  2018-08-03T14:50:00Z
# ...                                         ...                   ...
# 12786  e189043abcdc363a66270079341e45b9be50fe29  2018-08-31T17:15:00Z
# 12787  e189043abcdc363a66270079341e45b9be50fe29  2018-08-31T17:30:00Z
# 12788  e189043abcdc363a66270079341e45b9be50fe29  2018-08-31T17:20:00Z
# 12789  e189043abcdc363a66270079341e45b9be50fe29  2018-08-31T17:25:00Z
# 12790  e189043abcdc363a66270079341e45b9be50fe29  2018-08-31T17:35:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               688                      650
# 1         heat          hold               682                      650
# 2         heat          hold               690                      650
# 3         heat          hold               690                      650
# 4         heat          hold               670                      650
# ...        ...           ...               ...                      ...
# 12786     heat          hold               658                      690
# 12787     heat          hold               661                      690
# 12788     heat          hold               658                      690
# 12789     heat          hold               658                      690
# 12790     heat          hold               666                      690
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          610            AK  Anchorage                    0
# 1                          610            AK  Anchorage                    0
# 2                          610            AK  Anchorage                    0
# 3                          610            AK  Anchorage                    0
# 4                          610            AK  Anchorage                    0
# ...                        ...           ...        ...                  ...
# 12786                      690            AK  Anchorage                   30
# 12787                      690            AK  Anchorage                   30
# 12788                      690            AK  Anchorage                   30
# 12789                      690            AK  Anchorage                   30
# 12790                      690            AK  Anchorage                   30
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 12786             False         False            False
# 12787             False         False            False
# 12788             False         False            False
# 12789             False         False            False
# 12790             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 12786                       Gas
# 12787                       Gas
# 12788                       Gas
# 12789                       Gas
# 12790                       Gas
#
# [12220 rows x 14 columns]

# %%
# Add year and month

aug_2018["Year"] = "2018"
aug_2018["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2018 = aug_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
aug_2018_ave = aug_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2018_ave

# %%
# Export CSV file

aug_2018_ave.to_csv("data/day/AK/aug/aug_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 August Day

# %%
# Read in month csv for state
aug_2019 = pd.read_csv("../data_large/AK-day/2019-aug-day-AK.csv")

# aug_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
aug_2019.drop(aug_2019[aug_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
aug_2019.drop(aug_2019[aug_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
aug_2019.drop(aug_2019[aug_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
aug_2019.drop(aug_2019[aug_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

aug_2019
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     3c569abab42071063670722a0b326b0da8738423  2019-08-20T15:25:00Z     heat
# 1     3c569abab42071063670722a0b326b0da8738423  2019-08-20T15:55:00Z     heat
# 2     68a1a0651c36267368651a504b1a50737727928a  2019-08-27T17:10:00Z     heat
# 3     68a1a0651c36267368651a504b1a50737727928a  2019-08-22T19:25:00Z     heat
# 4     68a1a0651c36267368651a504b1a50737727928a  2019-08-20T16:05:00Z     heat
# ...                                        ...                   ...      ...
# 9874  b2926c336f48d0bdbcd5343bb68676b3a9364748  2019-08-18T17:25:00Z     heat
# 9875  b2926c336f48d0bdbcd5343bb68676b3a9364748  2019-08-18T17:35:00Z     heat
# 9876  b2926c336f48d0bdbcd5343bb68676b3a9364748  2019-08-22T15:55:00Z     heat
# 9877  b2926c336f48d0bdbcd5343bb68676b3a9364748  2019-08-22T14:50:00Z     heat
# 9878  b2926c336f48d0bdbcd5343bb68676b3a9364748  2019-08-18T17:45:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               707                      714
# 1             hold               700                      781
# 2             auto               695                      804
# 3             auto               683                      802
# 4             auto               684                      806
# ...            ...               ...                      ...
# 9874          hold               666                      690
# 9875          hold               676                      690
# 9876          hold               687                      690
# 9877          hold               677                      690
# 9878          hold               687                      690
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         698            AK  Anchorage                   25
# 1                         669            AK  Anchorage                   25
# 2                         632            AK  Anchorage                   40
# 3                         636            AK  Anchorage                   40
# 4                         628            AK  Anchorage                   40
# ...                       ...           ...        ...                  ...
# 9874                      690            AK      Healy                   10
# 9875                      690            AK      Healy                   10
# 9876                      690            AK      Healy                   10
# 9877                      690            AK      Healy                   10
# 9878                      690            AK      Healy                   10
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 9874             False         False            False
# 9875             False         False            False
# 9876             False         False            False
# 9877             False         False            False
# 9878             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 9874                       Gas
# 9875                       Gas
# 9876                       Gas
# 9877                       Gas
# 9878                       Gas
#
# [7811 rows x 14 columns]

# %%
# Add year and month

aug_2019["Year"] = "2019"
aug_2019["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2019 = aug_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
aug_2019_ave = aug_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2019_ave

# %%
# Export CSV file

aug_2019_ave.to_csv("data/day/AK/aug/aug_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 August Day

# %%
# Read in month csv for state
aug_2020 = pd.read_csv("../data_large/AK-day/2020-aug-day-AK.csv")

# aug_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
aug_2020.drop(aug_2020[aug_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
aug_2020.drop(aug_2020[aug_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
aug_2020.drop(aug_2020[aug_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
aug_2020.drop(aug_2020[aug_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

aug_2020
# Out:
#                                     Identifier             date_time HvacMode  \
# 0     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-08-06T19:25:00Z     heat
# 1     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-08-06T17:55:00Z     heat
# 2     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-08-11T19:05:00Z     heat
# 3     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-08-06T18:15:00Z     heat
# 4     0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183  2020-08-06T18:35:00Z     heat
# ...                                        ...                   ...      ...
# 7777  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-08-12T18:05:00Z     heat
# 7778  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-08-12T17:45:00Z     heat
# 7779  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-08-12T17:40:00Z     heat
# 7780  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-08-12T18:30:00Z     heat
# 7781  e607ef283e0f21c02dcd7df409ee3e764d229b79  2020-08-12T18:40:00Z     heat
#
#      CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0             hold               715                      715
# 1             hold               704                      715
# 2             hold               681                      776
# 3             hold               713                      715
# 4             hold               714                      715
# ...            ...               ...                      ...
# 7777          hold               710                      690
# 7778          hold               708                      690
# 7779          hold               706                      690
# 7780          hold               705                      690
# 7781          hold               701                      690
#
#       TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                         715            AK  Anchorage                   20
# 1                         715            AK  Anchorage                   20
# 2                         644            AK  Anchorage                   20
# 3                         715            AK  Anchorage                   20
# 4                         715            AK  Anchorage                   20
# ...                       ...           ...        ...                  ...
# 7777                      690            AK     Juneau                   50
# 7778                      690            AK     Juneau                   50
# 7779                      690            AK     Juneau                   50
# 7780                      690            AK     Juneau                   50
# 7781                      690            AK     Juneau                   50
#
#       allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                False         False            False
# 1                False         False            False
# 2                False         False            False
# 3                False         False            False
# 4                False         False            False
# ...                ...           ...              ...
# 7777             False         False            False
# 7778             False         False            False
# 7779             False         False            False
# 7780             False         False            False
# 7781             False         False            False
#
#      Auxilliary_Heat_Fuel_Type
# 0                          Gas
# 1                          Gas
# 2                          Gas
# 3                          Gas
# 4                          Gas
# ...                        ...
# 7777                       Gas
# 7778                       Gas
# 7779                       Gas
# 7780                       Gas
# 7781                       Gas
#
# [5546 rows x 14 columns]

# %%
# Add year and month

aug_2020["Year"] = "2020"
aug_2020["Month"] = "aug"

# %%
# Rename columns to label the aggregates

aug_2020 = aug_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
aug_2020_ave = aug_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# aug_2020_ave

# %%
# Export CSV file

aug_2020_ave.to_csv("data/day/AK/aug/aug_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/aug/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_aug = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/aug/" + file)
    AK_aug = pd.concat([AK_aug, df])
    
AK_aug
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 2   1544f3165814ae017488964fc29ae302bba75bb7   aug  2017     heat
# 3   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# 4   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# ..                                       ...   ...   ...      ...
# 15  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   aug  2020     heat
# 16  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   aug  2020     heat
# 17  e189043abcdc363a66270079341e45b9be50fe29   aug  2020     heat
# 18  e607ef283e0f21c02dcd7df409ee3e764d229b79   aug  2020     heat
# 19  ea9f45a49e23bc298fc582a4ad9e006b53853255   aug  2020     heat
#
#    CalendarEvent       City  Temperature_ctrl_ave  \
# 0           auto      Homer            669.857143
# 1           hold      Homer            666.275641
# 2           auto     juneau            690.291667
# 3           auto  Anchorage            689.200000
# 4           hold  Anchorage            689.015873
# ..           ...        ...                   ...
# 15          auto     juneau            693.087500
# 16          hold     juneau            682.761905
# 17          hold  Anchorage            611.307692
# 18          hold     Juneau            705.327869
# 19          hold     Bethel            675.666667
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    684.642857                   682.285714
# 1                    673.346154                   669.134615
# 2                    690.000000                   690.000000
# 3                    688.500000                   670.900000
# 4                    650.000000                   630.492063
# ..                          ...                          ...
# 15                   720.000000                   698.500000
# 16                   690.000000                   690.000000
# 17                   660.000000                   660.000000
# 18                   707.950820                   707.434426
# 19                   790.000000                   790.000000
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                   0.0              True         False            False
# 2                  27.0             False         False            False
# 3                   0.0             False         False            False
# 4                   0.0             False         False            False
# ..                  ...               ...           ...              ...
# 15                 27.0             False         False            False
# 16                 27.0             False         False            False
# 17                 30.0             False         False            False
# 18                 50.0             False         False            False
# 19                 49.0             False         False            False
#
# [78 rows x 13 columns]

# %%
AK_aug.to_csv("Scraper_Output/State_Month_Day/AK/AK_aug.csv", header=True, index=False)

# %% [markdown]
# ---
#
# ## September

# %% [markdown]
# ---
#
# ## October

# %% [markdown]
# ---
#
# ## November

# %% [markdown]
# ---
#
# ## December

# %% [markdown]
# ### 2017 December Day

# %%
# Read in month csv for state
dec_2017 = pd.read_csv("../data_large/AK-day/2017-dec-day-AK.csv")

# dec_2017

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
dec_2017.drop(dec_2017[dec_2017['TemperatureExpectedCool'] >= 850].index, inplace = True)
dec_2017.drop(dec_2017[dec_2017['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
dec_2017.drop(dec_2017[dec_2017['TemperatureExpectedCool'] <= 600].index, inplace = True)
dec_2017.drop(dec_2017[dec_2017['TemperatureExpectedHeat'] <= 600].index, inplace = True)

dec_2017
# Out:
#                                      Identifier             date_time  \
# 0      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2017-12-19T16:20:00Z
# 1      be4f2a63b7719c2a69aa285e8a38038c29df8fa6  2017-12-15T09:40:00Z
# 2      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2017-12-22T07:50:00Z
# 3      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2017-12-22T07:20:00Z
# 4      18c482b133fba9f05f7edac61214d7cd1082ff1a  2017-12-09T17:55:00Z
# ...                                         ...                   ...
# 11703  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-12-28T11:50:00Z
# 11704  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-12-28T13:20:00Z
# 11705  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-12-28T11:40:00Z
# 11706  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-12-28T12:35:00Z
# 11707  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572  2017-12-28T11:10:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               654                      691
# 1         heat          auto               664                      686
# 2         heat          auto               661                      650
# 3         heat          hold               658                      677
# 4         heat          hold               672                      695
# ...        ...           ...               ...                      ...
# 11703     heat          hold               722                      730
# 11704     heat          hold               727                      730
# 11705     heat          hold               726                      730
# 11706     heat          hold               724                      730
# 11707     heat          hold               721                      730
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          666            AK     Palmer                   25
# 1                          674            AK  Anchorage                    0
# 2                          609            AK     Palmer                   25
# 3                          659            AK     Palmer                   25
# 4                          678            AK  Anchorage                    5
# ...                        ...           ...        ...                  ...
# 11703                      730            AK     juneau                   27
# 11704                      730            AK     juneau                   27
# 11705                      730            AK     juneau                   27
# 11706                      730            AK     juneau                   27
# 11707                      730            AK     juneau                   27
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 11703             False         False            False
# 11704             False         False            False
# 11705             False         False            False
# 11706             False         False            False
# 11707             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 11703                       Gas
# 11704                       Gas
# 11705                       Gas
# 11706                       Gas
# 11707                       Gas
#
# [11312 rows x 14 columns]

# %%
# Add year and month

dec_2017["Year"] = "2017"
dec_2017["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2017 = dec_2017.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
dec_2017_ave = dec_2017.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2017_ave

# %%
# Export CSV file

dec_2017_ave.to_csv("data/day/AK/dec/dec_2017_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2018 December Day

# %%
# Read in month csv for state
dec_2018 = pd.read_csv("../data_large/AK-day/2018-dec-day-AK.csv")

# dec_2018

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
dec_2018.drop(dec_2018[dec_2018['TemperatureExpectedCool'] >= 850].index, inplace = True)
dec_2018.drop(dec_2018[dec_2018['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
dec_2018.drop(dec_2018[dec_2018['TemperatureExpectedCool'] <= 600].index, inplace = True)
dec_2018.drop(dec_2018[dec_2018['TemperatureExpectedHeat'] <= 600].index, inplace = True)

dec_2018
# Out:
#                                      Identifier             date_time  \
# 0      a799538555e2fb23d035a9aa0004122110571484  2018-12-26T19:05:00Z
# 1      bdc58f9e6d012d051afe58172dc008bebf29a356  2018-12-15T08:05:00Z
# 2      31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff  2018-12-05T07:20:00Z
# 3      bdc58f9e6d012d051afe58172dc008bebf29a356  2018-12-04T15:55:00Z
# 4      bdc58f9e6d012d051afe58172dc008bebf29a356  2018-12-10T14:35:00Z
# ...                                         ...                   ...
# 17957  c810efa572eb24b685d4ea14eb98d7f79cac0bd3  2018-12-22T07:10:00Z
# 17958  c810efa572eb24b685d4ea14eb98d7f79cac0bd3  2018-12-23T07:10:00Z
# 17959  c810efa572eb24b685d4ea14eb98d7f79cac0bd3  2018-12-24T07:45:00Z
# 17960  c810efa572eb24b685d4ea14eb98d7f79cac0bd3  2018-12-22T17:30:00Z
# 17961  c810efa572eb24b685d4ea14eb98d7f79cac0bd3  2018-12-24T19:20:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               688                      736
# 1         heat          hold               696                      727
# 2         heat          hold               695                      740
# 3         heat          auto               700                      700
# 4         heat          auto               666                      662
# ...        ...           ...               ...                      ...
# 17957     heat          hold               674                      680
# 17958     heat          hold               671                      680
# 17959     heat          hold               618                      680
# 17960     heat          hold               676                      680
# 17961     heat          hold               687                      680
#
#        TemperatureExpectedHeat ProvinceState              City  \
# 0                          677            AK         Anchorage
# 1                          727            AK  Huffman/O'Malley
# 2                          685            AK         Anchorage
# 3                          668            AK  Huffman/O'Malley
# 4                          662            AK  Huffman/O'Malley
# ...                        ...           ...               ...
# 17957                      680            AK        North Pole
# 17958                      680            AK        North Pole
# 17959                      680            AK        North Pole
# 17960                      680            AK        North Pole
# 17961                      680            AK        North Pole
#
#        Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                       40             False         False            False
# 1                       40             False         False            False
# 2                       25             False         False            False
# 3                       40             False         False            False
# 4                       40             False         False            False
# ...                    ...               ...           ...              ...
# 17957                    0             False         False            False
# 17958                    0             False         False            False
# 17959                    0             False         False            False
# 17960                    0             False         False            False
# 17961                    0             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 17957                       Gas
# 17958                       Gas
# 17959                       Gas
# 17960                       Gas
# 17961                       Gas
#
# [14335 rows x 14 columns]

# %%
# Add year and month

dec_2018["Year"] = "2018"
dec_2018["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2018 = dec_2018.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
dec_2018_ave = dec_2018.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2018_ave

# %%
# Export CSV file

dec_2018_ave.to_csv("data/day/AK/dec/dec_2018_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2019 December Day

# %%
# Read in month csv for state
dec_2019 = pd.read_csv("../data_large/AK-day/2019-dec-day-AK.csv")

# dec_2019

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
dec_2019.drop(dec_2019[dec_2019['TemperatureExpectedCool'] >= 850].index, inplace = True)
dec_2019.drop(dec_2019[dec_2019['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
dec_2019.drop(dec_2019[dec_2019['TemperatureExpectedCool'] <= 600].index, inplace = True)
dec_2019.drop(dec_2019[dec_2019['TemperatureExpectedHeat'] <= 600].index, inplace = True)

dec_2019
# Out:
#                                      Identifier             date_time  \
# 0      31ec2a66ddeac26df7dbbeffa7f98c4e2de26aff  2019-12-09T18:30:00Z
# 1      1934269f8f3a7a065318ec9a4e7984c0d9216332  2019-12-15T19:35:00Z
# 2      1934269f8f3a7a065318ec9a4e7984c0d9216332  2019-12-15T19:30:00Z
# 3      1934269f8f3a7a065318ec9a4e7984c0d9216332  2019-12-15T19:45:00Z
# 4      391a6ce2e4f243b7965dfc6004d6e8fc4cc7936e  2019-12-23T14:00:00Z
# ...                                         ...                   ...
# 17913  e607ef283e0f21c02dcd7df409ee3e764d229b79  2019-12-21T18:50:00Z
# 17914  e607ef283e0f21c02dcd7df409ee3e764d229b79  2019-12-21T16:25:00Z
# 17915  e607ef283e0f21c02dcd7df409ee3e764d229b79  2019-12-21T18:45:00Z
# 17916  e607ef283e0f21c02dcd7df409ee3e764d229b79  2019-12-22T19:45:00Z
# 17917  e607ef283e0f21c02dcd7df409ee3e764d229b79  2019-12-21T17:45:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               667                      763
# 1         heat          hold               671                      672
# 2         heat          hold               671                      672
# 3         heat          hold               671                      672
# 4         heat          hold               697                      746
# ...        ...           ...               ...                      ...
# 17913     heat          hold               721                      740
# 17914     heat          hold               729                      740
# 17915     heat          hold               721                      740
# 17916     heat          hold               746                      740
# 17917     heat          hold               729                      740
#
#        TemperatureExpectedHeat ProvinceState       City  Age_of_Home__years_  \
# 0                          653            AK  Anchorage                   25
# 1                          672            AK    Wasilla                    0
# 2                          672            AK    Wasilla                    0
# 3                          672            AK    Wasilla                    0
# 4                          686            AK     Palmer                   25
# ...                        ...           ...        ...                  ...
# 17913                      740            AK     Juneau                   50
# 17914                      740            AK     Juneau                   50
# 17915                      740            AK     Juneau                   50
# 17916                      740            AK     Juneau                   50
# 17917                      740            AK     Juneau                   50
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 17913             False         False            False
# 17914             False         False            False
# 17915             False         False            False
# 17916             False         False            False
# 17917             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 17913                       Gas
# 17914                       Gas
# 17915                       Gas
# 17916                       Gas
# 17917                       Gas
#
# [11099 rows x 14 columns]

# %%
# Add year and month

dec_2019["Year"] = "2019"
dec_2019["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2019 = dec_2019.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
dec_2019_ave = dec_2019.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2019_ave

# %%
# Export CSV file

dec_2019_ave.to_csv("data/day/AK/dec/dec_2019_ave.csv", header=True, index=True)

# %% [markdown]
# ### 2020 December Day

# %%
# Read in month csv for state
dec_2020 = pd.read_csv("../data_large/AK-day/2020-dec-day-AK.csv")

# dec_2020

# %%
# Remove predetermined outliers before aggregating.
# TemperatureExpectedCool >= 850
dec_2020.drop(dec_2020[dec_2020['TemperatureExpectedCool'] >= 850].index, inplace = True)
dec_2020.drop(dec_2020[dec_2020['TemperatureExpectedHeat'] >= 850].index, inplace = True)

# TemperatureExpectedHeat <= 600
dec_2020.drop(dec_2020[dec_2020['TemperatureExpectedCool'] <= 600].index, inplace = True)
dec_2020.drop(dec_2020[dec_2020['TemperatureExpectedHeat'] <= 600].index, inplace = True)

dec_2020
# Out:
#                                      Identifier             date_time  \
# 0      1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-12-18T18:40:00Z
# 1      1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-12-18T17:25:00Z
# 2      1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-12-05T18:35:00Z
# 3      1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-12-05T18:40:00Z
# 4      1934269f8f3a7a065318ec9a4e7984c0d9216332  2020-12-18T17:50:00Z
# ...                                         ...                   ...
# 10903  ea9f45a49e23bc298fc582a4ad9e006b53853255  2020-12-17T15:35:00Z
# 10904  ea9f45a49e23bc298fc582a4ad9e006b53853255  2020-12-17T07:10:00Z
# 10905  ea9f45a49e23bc298fc582a4ad9e006b53853255  2020-12-17T16:55:00Z
# 10906  ea9f45a49e23bc298fc582a4ad9e006b53853255  2020-12-17T15:45:00Z
# 10907  ea9f45a49e23bc298fc582a4ad9e006b53853255  2020-12-17T07:15:00Z
#
#       HvacMode CalendarEvent  Temperature_ctrl  TemperatureExpectedCool  \
# 0         heat          hold               617                      682
# 1         heat          hold               617                      682
# 2         heat          hold               648                      679
# 3         heat          hold               652                      679
# 4         heat          hold               633                      682
# ...        ...           ...               ...                      ...
# 10903     heat          hold               729                      730
# 10904     heat          hold               741                      730
# 10905     heat          hold               725                      730
# 10906     heat          hold               729                      730
# 10907     heat          hold               738                      730
#
#        TemperatureExpectedHeat ProvinceState     City  Age_of_Home__years_  \
# 0                          682            AK  Wasilla                    0
# 1                          682            AK  Wasilla                    0
# 2                          679            AK  Wasilla                    0
# 3                          679            AK  Wasilla                    0
# 4                          682            AK  Wasilla                    0
# ...                        ...           ...      ...                  ...
# 10903                      730            AK   Bethel                   49
# 10904                      730            AK   Bethel                   49
# 10905                      730            AK   Bethel                   49
# 10906                      730            AK   Bethel                   49
# 10907                      730            AK   Bethel                   49
#
#        allowCompWithAux  Has_Electric  Has_a_Heat_Pump  \
# 0                 False         False            False
# 1                 False         False            False
# 2                 False         False            False
# 3                 False         False            False
# 4                 False         False            False
# ...                 ...           ...              ...
# 10903             False         False            False
# 10904             False         False            False
# 10905             False         False            False
# 10906             False         False            False
# 10907             False         False            False
#
#       Auxilliary_Heat_Fuel_Type
# 0                           Gas
# 1                           Gas
# 2                           Gas
# 3                           Gas
# 4                           Gas
# ...                         ...
# 10903                       Gas
# 10904                       Gas
# 10905                       Gas
# 10906                       Gas
# 10907                       Gas
#
# [5781 rows x 14 columns]

# %%
# Add year and month

dec_2020["Year"] = "2020"
dec_2020["Month"] = "dec"

# %%
# Rename columns to label the aggregates

dec_2020 = dec_2020.rename(columns={"Temperature_ctrl":"Temperature_ctrl_ave", 
                         "TemperatureExpectedCool":"TemperatureExpectedCool_ave", 
                         "TemperatureExpectedHeat":"TemperatureExpectedHeat_ave"})

# %%
dec_2020_ave = dec_2020.groupby(['Identifier', 'Month', 'Year','HvacMode','CalendarEvent', 'City']).mean()

# dec_2020_ave

# %%
# Export CSV file

dec_2020_ave.to_csv("data/day/AK/dec/dec_2020_ave.csv", header=True, index=True)

# %% [markdown]
# ---
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/AK/dec/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_dec = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/AK/dec/" + file)
    AK_dec = pd.concat([AK_dec, df])
    
AK_dec
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   dec  2017     heat
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f   dec  2017     heat
# 2   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   dec  2017     heat
# 3   0e0d17a6d14f69ec9ccaa6e561c3d01e409ee183   dec  2017     heat
# 4   18c482b133fba9f05f7edac61214d7cd1082ff1a   dec  2017     heat
# ..                                       ...   ...   ...      ...
# 18  be4f2a63b7719c2a69aa285e8a38038c29df8fa6   dec  2020     heat
# 19  d52d6af22f2bcad8215f8eec1a710dd00e190c7b   dec  2020     heat
# 20  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   dec  2020     heat
# 21  e607ef283e0f21c02dcd7df409ee3e764d229b79   dec  2020     heat
# 22  ea9f45a49e23bc298fc582a4ad9e006b53853255   dec  2020     heat
#
#    CalendarEvent       City  Temperature_ctrl_ave  \
# 0           auto      Homer            668.024390
# 1           hold      Homer            671.319797
# 2           auto  Anchorage            650.607843
# 3           hold  Anchorage            643.820755
# 4           auto  Anchorage            661.787879
# ..           ...        ...                   ...
# 18          hold  Anchorage            687.800000
# 19          hold    Wasilla            645.871795
# 20          auto     juneau            681.916667
# 21          hold     Juneau            692.929825
# 22          hold     Bethel            696.328042
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    662.439024                   622.219512
# 1                    663.700508                   655.451777
# 2                    665.882353                   661.176471
# 3                    656.962264                   646.698113
# 4                    728.787879                   650.303030
# ..                          ...                          ...
# 18                   678.800000                   671.600000
# 19                   650.000000                   650.000000
# 20                   700.000000                   700.000000
# 21                   715.684211                   714.149123
# 22                   699.444444                   696.587302
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                   0.0              True         False            False
# 2                  20.0             False         False            False
# 3                  20.0             False         False            False
# 4                   5.0             False         False            False
# ..                  ...               ...           ...              ...
# 18                  0.0             False         False            False
# 19                  5.0             False         False            False
# 20                 27.0             False         False            False
# 21                 50.0             False         False            False
# 22                 49.0             False         False            False
#
# [145 rows x 13 columns]

# %%
AK_dec.to_csv("Scraper_Output/State_Month_Day/AK/AK_dec.csv", header=True, index=False)

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# ---
#
# ### Combine state CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV

# %%
# Create variable for files in directory
files = [f for f in os.listdir("Scraper_Output/State_Month_Day/AK/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AK_all = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("Scraper_Output/State_Month_Day/AK/" + file)
    AK_all = pd.concat([AK_all, df])
    
AK_all
# Out:
#                                   Identifier Month  Year HvacMode  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 2   1544f3165814ae017488964fc29ae302bba75bb7   aug  2017     heat
# 3   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# 4   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# ..                                       ...   ...   ...      ...
# 77  995e1c96a74ee2cb3509db751eb6310b63e5aa94   jun  2021     heat
# 78  bdc58f9e6d012d051afe58172dc008bebf29a356   jun  2021     heat
# 79  df7ad0ff0b54c69d3f2cdeda3b12bff79713d572   jun  2021     heat
# 80  e189043abcdc363a66270079341e45b9be50fe29   jun  2021     heat
# 81  e607ef283e0f21c02dcd7df409ee3e764d229b79   jun  2021     heat
#
#    CalendarEvent              City  Temperature_ctrl_ave  \
# 0           auto             Homer            669.857143
# 1           hold             Homer            666.275641
# 2           auto            juneau            690.291667
# 3           auto         Anchorage            689.200000
# 4           hold         Anchorage            689.015873
# ..           ...               ...                   ...
# 77          hold         Anchorage            680.368490
# 78          hold  Huffman/O'Malley            679.000000
# 79          hold            juneau            702.277778
# 80          hold         Anchorage            650.250000
# 81          hold            Juneau            700.432432
#
#     TemperatureExpectedCool_ave  TemperatureExpectedHeat_ave  \
# 0                    684.642857                   682.285714
# 1                    673.346154                   669.134615
# 2                    690.000000                   690.000000
# 3                    688.500000                   670.900000
# 4                    650.000000                   630.492063
# ..                          ...                          ...
# 77                   672.600260                   656.790365
# 78                   674.333333                   669.333333
# 79                   653.194444                   653.166667
# 80                   780.250000                   649.062500
# 81                   741.648649                   738.351351
#
#     Age_of_Home__years_  allowCompWithAux  Has_Electric  Has_a_Heat_Pump
# 0                   0.0              True         False            False
# 1                   0.0              True         False            False
# 2                  27.0             False         False            False
# 3                   0.0             False         False            False
# 4                   0.0             False         False            False
# ..                  ...               ...           ...              ...
# 77                 35.0             False         False            False
# 78                 40.0             False         False            False
# 79                 27.0             False         False            False
# 80                 30.0             False         False            False
# 81                 50.0             False         False            False
#
# [658 rows x 13 columns]

# %%
AK_all.to_csv("Scraper_Output/State_Month_Day/AK_all_day.csv", header=True, index=False)

# %%
# Datacheck to make sure state was selected correctly in BQ sql queries

print(f"Unique jan_2017: {jan_2017['ProvinceState'].unique()}")
print(f"Unique jan_2018: {jan_2018['ProvinceState'].unique()}")
print(f"Unique jan_2019: {jan_2019['ProvinceState'].unique()}")
print(f"Unique jan_2020: {jan_2020['ProvinceState'].unique()}")
print(f"Unique jan_2021: {jan_2021['ProvinceState'].unique()}")
print(f"Unique feb_2017: {feb_2017['ProvinceState'].unique()}")
print(f"Unique feb_2018: {feb_2018['ProvinceState'].unique()}")
print(f"Unique feb_2019: {feb_2019['ProvinceState'].unique()}")
print(f"Unique feb_2020: {feb_2020['ProvinceState'].unique()}")
print(f"Unique feb_2021: {feb_2021['ProvinceState'].unique()}")
print(f"Unique jun_2017: {jun_2017['ProvinceState'].unique()}")
print(f"Unique jun_2018: {jun_2018['ProvinceState'].unique()}")
print(f"Unique jun_2019: {jun_2019['ProvinceState'].unique()}")
print(f"Unique jun_2020: {jun_2020['ProvinceState'].unique()}")
print(f"Unique jun_2021: {jun_2021['ProvinceState'].unique()}")
print(f"Unique jul_2017: {jul_2017['ProvinceState'].unique()}")
print(f"Unique jul_2018: {jul_2018['ProvinceState'].unique()}")
print(f"Unique jul_2019: {jul_2019['ProvinceState'].unique()}")
print(f"Unique jul_2020: {jul_2020['ProvinceState'].unique()}")
print(f"Unique jul_2021: {jul_2021['ProvinceState'].unique()}")
print(f"Unique aug_2017: {aug_2017['ProvinceState'].unique()}")
print(f"Unique aug_2018: {aug_2018['ProvinceState'].unique()}")
print(f"Unique aug_2019: {aug_2019['ProvinceState'].unique()}")
print(f"Unique aug_2020: {aug_2020['ProvinceState'].unique()}")
print(f"Unique dec_2017: {dec_2017['ProvinceState'].unique()}")
print(f"Unique dec_2018: {dec_2018['ProvinceState'].unique()}")
print(f"Unique dec_2019: {dec_2019['ProvinceState'].unique()}")
print(f"Unique dec_2020: {dec_2020['ProvinceState'].unique()}")
# Out:
# Unique jan_2017: ['AK']
# Unique jan_2018: ['AK']
# Unique jan_2019: ['AK']
# Unique jan_2020: ['AK']
# Unique jan_2021: ['AK']
# Unique feb_2017: ['AK']
# Unique feb_2018: ['AK']
# Unique feb_2019: ['AK']
# Unique feb_2020: ['AK']
# Unique feb_2021: ['AK']
# Unique jun_2017: ['AK']
# Unique jun_2018: ['AK']
# Unique jun_2019: ['AK']
# Unique jun_2020: ['AK']
# Unique jun_2021: ['AK']
# Unique jul_2017: ['AK']
# Unique jul_2018: ['AK']
# Unique jul_2019: ['AK']
# Unique jul_2020: ['AK']
# Unique jul_2021: ['AK']
# Unique aug_2017: ['AK']
# Unique aug_2018: ['AK']
# Unique aug_2019: ['AK']
# Unique aug_2020: ['AK']
# Unique dec_2017: ['AK']
# Unique dec_2018: ['AK']
# Unique dec_2019: ['AK']
# Unique dec_2020: ['AK']
