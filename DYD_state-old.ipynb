# %% [markdown]
# # DYD Thermostat Data
#
# ## Preprocess
#
# 1. Generated CSV file from queries in BigQueary
#
# 2. Data separated into states
#
# 3. Aggregated the data in BigQuery by vintage of home (every 5 years) and by month

# %%
# Dependencies
import pandas as pd
import os
import numpy as np
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ---
#
# ## Combine state CSV Files
# 1. Read in files in folders by year and month
# 2. Add year and month to each merged file

# %% [markdown]
# ### 2017 January Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/jan/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
jan_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/jan/" + file)
    jan_2017 = pd.concat([jan_2017, df])
    
jan_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    674.860140  671.552448  665.972028
# 1    700.400000  697.600000  697.600000
# 2    689.749196  766.485531  685.254019
# 3    700.015385  703.780000  703.647692
# 4    644.954545  710.000000  710.000000
# ..          ...         ...         ...
# 9    675.750000  730.000000  680.000000
# 10   715.203046  724.822335  724.822335
# 11   722.718750  775.000000  725.000000
# 12   690.000000  722.000000  672.000000
# 0    735.030303  788.787879  738.303030
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 9   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 11  3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 12  527196dd67df36085c7eb0f7137ef298e0bb60b1      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#             City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0      Anchorage                    0     heat          auto    Home
# 1      Anchorage                    0     heat          hold    Home
# 2        Wasilla                    0     heat          auto    Home
# 3        Wasilla                    0     heat          hold    Home
# 4         Palmer                    0     heat          hold    Home
# ..           ...                  ...      ...           ...     ...
# 9     Maidsville                    0     auto          hold    Home
# 10    Huntington                    0     cool          auto    Home
# 11    Morgantown                    0     auto          auto    Home
# 12  Charles Town                    0     auto          auto    Home
# 0       Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 11              True         False             True                  Electric
# 12             False         False            False                       Gas
# 0              False         False            False                       Gas
#
# [5865 rows x 15 columns]

# %%
# See all the unique names for states

# jan_2017.ProvinceState.unique()

# %%
# Add year and month

jan_2017["Year"] = "2017"
jan_2017["Month"] = "Jan"

jan_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    674.860140  671.552448  665.972028
# 1    700.400000  697.600000  697.600000
# 2    689.749196  766.485531  685.254019
# 3    700.015385  703.780000  703.647692
# 4    644.954545  710.000000  710.000000
# ..          ...         ...         ...
# 9    675.750000  730.000000  680.000000
# 10   715.203046  724.822335  724.822335
# 11   722.718750  775.000000  725.000000
# 12   690.000000  722.000000  672.000000
# 0    735.030303  788.787879  738.303030
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 9   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 11  3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 12  527196dd67df36085c7eb0f7137ef298e0bb60b1      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#             City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0      Anchorage                    0     heat          auto    Home
# 1      Anchorage                    0     heat          hold    Home
# 2        Wasilla                    0     heat          auto    Home
# 3        Wasilla                    0     heat          hold    Home
# 4         Palmer                    0     heat          hold    Home
# ..           ...                  ...      ...           ...     ...
# 9     Maidsville                    0     auto          hold    Home
# 10    Huntington                    0     cool          auto    Home
# 11    Morgantown                    0     auto          auto    Home
# 12  Charles Town                    0     auto          auto    Home
# 0       Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 11              True         False             True                  Electric
# 12             False         False            False                       Gas
# 0              False         False            False                       Gas
#
#     Year Month
# 0   2017   Jan
# 1   2017   Jan
# 2   2017   Jan
# 3   2017   Jan
# 4   2017   Jan
# ..   ...   ...
# 9   2017   Jan
# 10  2017   Jan
# 11  2017   Jan
# 12  2017   Jan
# 0   2017   Jan
#
# [5865 rows x 17 columns]

# %% [markdown]
# ### 2017 February Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/feb/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
feb_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/feb/" + file)
    feb_2017 = pd.concat([feb_2017, df])
    
feb_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    694.970588  682.500000  680.735294
# 1    685.013699  686.835616  686.109589
# 2    593.161905  759.380952  655.857143
# 3    628.294118  650.000000  620.000000
# 4    718.041270  720.095238  719.950794
# ..          ...         ...         ...
# 7    719.593291  727.259958  707.297694
# 8    729.894097  776.666667  726.666667
# 9    705.145455  775.000000  725.000000
# 10   741.208333  738.500000  738.500000
# 0    657.339286  740.000000  660.000000
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# ..                                       ...     ...           ...
# 7   0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 8   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 9   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0    Anchorage                    0     heat          auto    Home
# 1        Homer                    0     heat          hold    Home
# 2       Palmer                    0     heat          auto    Home
# 3       Palmer                    0     heat          hold    Home
# 4      Wasilla                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 7   Huntington                    0     auto          auto    Home
# 8   Morgantown                    0     auto          hold    Home
# 9   Morgantown                    0     auto          auto    Home
# 10  Huntington                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0              False         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 0              False         False            False                       Gas
#
# [6041 rows x 15 columns]

# %%
# Add year and month

feb_2017["Year"] = "2017"
feb_2017["Month"] = "Feb"

feb_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    694.970588  682.500000  680.735294
# 1    685.013699  686.835616  686.109589
# 2    593.161905  759.380952  655.857143
# 3    628.294118  650.000000  620.000000
# 4    718.041270  720.095238  719.950794
# ..          ...         ...         ...
# 7    719.593291  727.259958  707.297694
# 8    729.894097  776.666667  726.666667
# 9    705.145455  775.000000  725.000000
# 10   741.208333  738.500000  738.500000
# 0    657.339286  740.000000  660.000000
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# ..                                       ...     ...           ...
# 7   0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 8   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 9   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0    Anchorage                    0     heat          auto    Home
# 1        Homer                    0     heat          hold    Home
# 2       Palmer                    0     heat          auto    Home
# 3       Palmer                    0     heat          hold    Home
# 4      Wasilla                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 7   Huntington                    0     auto          auto    Home
# 8   Morgantown                    0     auto          hold    Home
# 9   Morgantown                    0     auto          auto    Home
# 10  Huntington                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0              False         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 0              False         False            False                       Gas
#
#     Year Month
# 0   2017   Feb
# 1   2017   Feb
# 2   2017   Feb
# 3   2017   Feb
# 4   2017   Feb
# ..   ...   ...
# 7   2017   Feb
# 8   2017   Feb
# 9   2017   Feb
# 10  2017   Feb
# 0   2017   Feb
#
# [6041 rows x 17 columns]

# %% [markdown]
# ### 2017 March Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/mar/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
mar_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/mar/" + file)
    mar_2017 = pd.concat([mar_2017, df])
    
mar_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    683.496144  681.197943  679.760925
# 1    686.531250  690.187500  683.406250
# 2    702.750000  650.000000  646.250000
# 3    595.928571  733.301587  663.563492
# 4    694.961397  697.871324  694.862132
# ..          ...         ...         ...
# 9    729.905797  778.043478  725.434783
# 10   724.534577  728.379802  728.230516
# 11   722.788136  720.338983  726.262712
# 12   723.314286  724.653061  724.653061
# 0    688.609155  759.436620  691.725352
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# ..                                       ...     ...           ...
# 9   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 11  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 12  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Homer                    0     heat          hold    Home
# 1        Homer                    0     heat          auto    Home
# 2        Homer                    0      off          hold    Home
# 3       Palmer                    0     heat          auto    Home
# 4      Wasilla                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 9   Morgantown                    0     auto          hold    Home
# 10  Huntington                    0     heat          auto    Home
# 11  Huntington                    0     cool          auto    Home
# 12  Huntington                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0               True         False            False                       Gas
# 1               True         False            False                       Gas
# 2               True         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 11             False         False            False                       Gas
# 12             False         False            False                       Gas
# 0              False         False            False                       Gas
#
# [7067 rows x 15 columns]

# %%
# Add year and month

mar_2017["Year"] = "2017"
mar_2017["Month"] = "Mar"

mar_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    683.496144  681.197943  679.760925
# 1    686.531250  690.187500  683.406250
# 2    702.750000  650.000000  646.250000
# 3    595.928571  733.301587  663.563492
# 4    694.961397  697.871324  694.862132
# ..          ...         ...         ...
# 9    729.905797  778.043478  725.434783
# 10   724.534577  728.379802  728.230516
# 11   722.788136  720.338983  726.262712
# 12   723.314286  724.653061  724.653061
# 0    688.609155  759.436620  691.725352
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# ..                                       ...     ...           ...
# 9   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 10  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 11  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 12  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Homer                    0     heat          hold    Home
# 1        Homer                    0     heat          auto    Home
# 2        Homer                    0      off          hold    Home
# 3       Palmer                    0     heat          auto    Home
# 4      Wasilla                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 9   Morgantown                    0     auto          hold    Home
# 10  Huntington                    0     heat          auto    Home
# 11  Huntington                    0     cool          auto    Home
# 12  Huntington                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0               True         False            False                       Gas
# 1               True         False            False                       Gas
# 2               True         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 9               True         False             True                  Electric
# 10             False         False            False                       Gas
# 11             False         False            False                       Gas
# 12             False         False            False                       Gas
# 0              False         False            False                       Gas
#
#     Year Month
# 0   2017   Mar
# 1   2017   Mar
# 2   2017   Mar
# 3   2017   Mar
# 4   2017   Mar
# ..   ...   ...
# 9   2017   Mar
# 10  2017   Mar
# 11  2017   Mar
# 12  2017   Mar
# 0   2017   Mar
#
# [7067 rows x 17 columns]

# %% [markdown]
# ### 2017 April Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/apr/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
apr_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/apr/" + file)
    apr_2017 = pd.concat([apr_2017, df])
    
apr_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    687.312500  664.000000  659.500000
# 1    681.337531  680.911839  678.256927
# 2    666.000000  752.000000  685.000000
# 3    717.121622  720.608108  719.695946
# 4    634.017857  650.000000  620.000000
# ..          ...         ...         ...
# 13   720.231092  763.571429  713.571429
# 14   728.316964  729.084821  709.361607
# 15   723.423188  726.275362  720.278261
# 0    740.763033  750.056872  735.658768
# 1    736.453608  731.216495  729.443299
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 13  3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 14  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 15  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Homer                    0     heat          auto    Home
# 1        Homer                    0     heat          hold    Home
# 2      Wasilla                    0     heat          hold    Home
# 3      Wasilla                    0     heat          auto    Home
# 4       Palmer                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 13  Morgantown                    0     auto          hold    Home
# 14  Huntington                    0     auto          auto    Home
# 15  Huntington                    0     cool          auto    Home
# 0     Cheyenne                    0     heat          auto    Home
# 1     Cheyenne                    0     heat          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0               True         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 13              True         False             True                  Electric
# 14             False         False            False                       Gas
# 15             False         False            False                       Gas
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
# [7584 rows x 15 columns]

# %%
# Add year and month

apr_2017["Year"] = "2017"
apr_2017["Month"] = "Apr"

apr_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    687.312500  664.000000  659.500000
# 1    681.337531  680.911839  678.256927
# 2    666.000000  752.000000  685.000000
# 3    717.121622  720.608108  719.695946
# 4    634.017857  650.000000  620.000000
# ..          ...         ...         ...
# 13   720.231092  763.571429  713.571429
# 14   728.316964  729.084821  709.361607
# 15   723.423188  726.275362  720.278261
# 0    740.763033  750.056872  735.658768
# 1    736.453608  731.216495  729.443299
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 13  3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 14  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 15  0294595998430fa9228ff8b203c54f8378f9560c      US            WV
# 0   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Homer                    0     heat          auto    Home
# 1        Homer                    0     heat          hold    Home
# 2      Wasilla                    0     heat          hold    Home
# 3      Wasilla                    0     heat          auto    Home
# 4       Palmer                    0     heat          hold    Home
# ..         ...                  ...      ...           ...     ...
# 13  Morgantown                    0     auto          hold    Home
# 14  Huntington                    0     auto          auto    Home
# 15  Huntington                    0     cool          auto    Home
# 0     Cheyenne                    0     heat          auto    Home
# 1     Cheyenne                    0     heat          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0               True         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 13              True         False             True                  Electric
# 14             False         False            False                       Gas
# 15             False         False            False                       Gas
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
#     Year Month
# 0   2017   Apr
# 1   2017   Apr
# 2   2017   Apr
# 3   2017   Apr
# 4   2017   Apr
# ..   ...   ...
# 13  2017   Apr
# 14  2017   Apr
# 15  2017   Apr
# 0   2017   Apr
# 1   2017   Apr
#
# [7584 rows x 17 columns]

# %% [markdown]
# ### 2017 May Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/may/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
may_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/may/" + file)
    may_2017 = pd.concat([may_2017, df])
    
may_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    687.872619  671.776190  671.626190
# 1    673.013605  672.510204  662.193878
# 2    680.991497  670.000000  670.000000
# 3    679.666667  680.000000  680.000000
# 4    692.717391  699.913043  696.326087
# ..          ...         ...         ...
# 6    712.457031  716.871094  666.871094
# 7    726.533520  741.502793  677.004190
# 8    756.384615  740.000000  740.000000
# 0    682.579139  762.199515  681.561552
# 1    727.869565  740.130435  701.826087
#
#                                   Identifier Country ProvinceState  \
# 0   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 4   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# ..                                       ...     ...           ...
# 6   c5b31dacb5cc3a1c181dbf7a905df96d0dfdc347      US            WV
# 7   c5b31dacb5cc3a1c181dbf7a905df96d0dfdc347      US            WV
# 8   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0      Wasilla                    0     heat          hold    Home
# 1        Homer                    0     heat          hold    Home
# 2      Wasilla                    0     heat          auto    Home
# 3    Anchorage                    0     heat          hold    Home
# 4    Anchorage                    0     heat          auto    Home
# ..         ...                  ...      ...           ...     ...
# 6   Morgantown                    0     auto          auto    Home
# 7   Morgantown                    0     auto          hold    Home
# 8   Morgantown                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
# 1     Cheyenne                    0     auto          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0              False         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 6              False         False            False                       Gas
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
# [8409 rows x 15 columns]

# %%
# Add year and month

may_2017["Year"] = "2017"
may_2017["Month"] = "May"

may_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    687.872619  671.776190  671.626190
# 1    673.013605  672.510204  662.193878
# 2    680.991497  670.000000  670.000000
# 3    679.666667  680.000000  680.000000
# 4    692.717391  699.913043  696.326087
# ..          ...         ...         ...
# 6    712.457031  716.871094  666.871094
# 7    726.533520  741.502793  677.004190
# 8    756.384615  740.000000  740.000000
# 0    682.579139  762.199515  681.561552
# 1    727.869565  740.130435  701.826087
#
#                                   Identifier Country ProvinceState  \
# 0   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 1   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 4   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# ..                                       ...     ...           ...
# 6   c5b31dacb5cc3a1c181dbf7a905df96d0dfdc347      US            WV
# 7   c5b31dacb5cc3a1c181dbf7a905df96d0dfdc347      US            WV
# 8   3a38dd3de8441afd6215d6a91bf033c2c646b786      US            WV
# 0   9d6a98350302417c9b2f10ae3c235d52a3bf7097      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#           City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0      Wasilla                    0     heat          hold    Home
# 1        Homer                    0     heat          hold    Home
# 2      Wasilla                    0     heat          auto    Home
# 3    Anchorage                    0     heat          hold    Home
# 4    Anchorage                    0     heat          auto    Home
# ..         ...                  ...      ...           ...     ...
# 6   Morgantown                    0     auto          auto    Home
# 7   Morgantown                    0     auto          hold    Home
# 8   Morgantown                    0     cool          hold    Home
# 0     Sheridan                    0     auto          hold    Home
# 1     Cheyenne                    0     auto          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0              False         False            False                       Gas
# 1               True         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 6              False         False            False                       Gas
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
#     Year Month
# 0   2017   May
# 1   2017   May
# 2   2017   May
# 3   2017   May
# 4   2017   May
# ..   ...   ...
# 6   2017   May
# 7   2017   May
# 8   2017   May
# 0   2017   May
# 1   2017   May
#
# [8409 rows x 17 columns]

# %% [markdown]
# ### 2017 June Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/jun/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
jun_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/jun/" + file)
    jun_2017 = pd.concat([jun_2017, df])
    
jun_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    691.066038  650.000000  650.000000
# 1    685.781657  654.857738  654.857738
# 2    668.244094  667.244094  660.929134
# 3    705.428571  736.285714  710.571429
# 4    695.549020  684.098039  683.823529
# ..          ...         ...         ...
# 4    686.971429  689.714286  629.428571
# 5    704.833333  680.000000  630.000000
# 6    692.975490  692.941176  630.000000
# 7    720.463436  720.000000  670.000000
# 8    681.350000  680.000000  690.000000
#
#                                   Identifier Country ProvinceState  \
# 0   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 1   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 4   f710bb7d9a4a4033f351d3fe907edc4564fe1892      US            WV
# 5   527196dd67df36085c7eb0f7137ef298e0bb60b1      US            WV
# 6   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 7   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
# 8   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
#
#             City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Wasilla                    0     heat          auto    Home
# 1        Wasilla                    0     heat          hold    Home
# 2          Homer                    0     heat          hold    Home
# 3         Palmer                    0     heat          auto    Home
# 4         Palmer                    0     heat          hold    Home
# ..           ...                  ...      ...           ...     ...
# 4     Morgantown                    0     auto          auto    Home
# 5   Charles Town                    0     auto          hold    Home
# 6     Maidsville                    0     auto          hold    Home
# 7     Morgantown                    0     auto          hold    Home
# 8     Maidsville                    0     cool          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2               True         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 4              False         False            False                       Gas
# 5              False         False            False                       Gas
# 6               True         False             True                  Electric
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
#
# [8027 rows x 15 columns]

# %%
# Add year and month

jun_2017["Year"] = "2017"
jun_2017["Month"] = "Jun"

jun_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    691.066038  650.000000  650.000000
# 1    685.781657  654.857738  654.857738
# 2    668.244094  667.244094  660.929134
# 3    705.428571  736.285714  710.571429
# 4    695.549020  684.098039  683.823529
# ..          ...         ...         ...
# 4    686.971429  689.714286  629.428571
# 5    704.833333  680.000000  630.000000
# 6    692.975490  692.941176  630.000000
# 7    720.463436  720.000000  670.000000
# 8    681.350000  680.000000  690.000000
#
#                                   Identifier Country ProvinceState  \
# 0   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 1   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ..                                       ...     ...           ...
# 4   f710bb7d9a4a4033f351d3fe907edc4564fe1892      US            WV
# 5   527196dd67df36085c7eb0f7137ef298e0bb60b1      US            WV
# 6   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 7   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
# 8   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
#
#             City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Wasilla                    0     heat          auto    Home
# 1        Wasilla                    0     heat          hold    Home
# 2          Homer                    0     heat          hold    Home
# 3         Palmer                    0     heat          auto    Home
# 4         Palmer                    0     heat          hold    Home
# ..           ...                  ...      ...           ...     ...
# 4     Morgantown                    0     auto          auto    Home
# 5   Charles Town                    0     auto          hold    Home
# 6     Maidsville                    0     auto          hold    Home
# 7     Morgantown                    0     auto          hold    Home
# 8     Maidsville                    0     cool          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2               True         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 4              False         False            False                       Gas
# 5              False         False            False                       Gas
# 6               True         False             True                  Electric
# 7              False         False            False                       Gas
# 8               True         False             True                  Electric
#
#     Year Month
# 0   2017   Jun
# 1   2017   Jun
# 2   2017   Jun
# 3   2017   Jun
# 4   2017   Jun
# ..   ...   ...
# 4   2017   Jun
# 5   2017   Jun
# 6   2017   Jun
# 7   2017   Jun
# 8   2017   Jun
#
# [8027 rows x 17 columns]

# %% [markdown]
# ### 2017 July Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/jul/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
jul_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/jul/" + file)
    jul_2017 = pd.concat([jul_2017, df])
    
jul_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    675.649123  673.706140  668.429825
# 1    694.370968  659.693548  652.322581
# 2    679.433362  652.528310  644.569251
# 3    686.586957  690.652174  677.173913
# 4    712.683215  650.000000  600.000000
# ..          ...         ...         ...
# 7    692.583841  690.759146  690.741616
# 8    690.450000  690.000000  690.000000
# 9    686.192771  674.638554  690.000000
# 0    751.487603  773.363636  698.429752
# 1    733.000000  723.000000  693.000000
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   c810efa572eb24b685d4ea14eb98d7f79cac0bd3      US            AK
# ..                                       ...     ...           ...
# 7   362159cb260bc35da7592691d97629ce9b8889ae      US            WV
# 8   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 9   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 0   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#            City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0         Homer                    0     heat          hold    Home
# 1        Palmer                    0     heat          hold    Home
# 2       Wasilla                    0     heat          hold    Home
# 3        Palmer                    0     heat          auto    Home
# 4    North Pole                    0     heat          hold    Home
# ..          ...                  ...      ...           ...     ...
# 7   Martinsburg                    0     cool          hold    Home
# 8    Maidsville                    0     cool          hold    Home
# 9    Maidsville                    0     cool          auto    Home
# 0      Cheyenne                    0     cool          auto    Home
# 1      Cheyenne                    0     auto          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0               True         False            False                       Gas
# 1              False         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 7              False         False             True                  Electric
# 8               True         False             True                  Electric
# 9               True         False             True                  Electric
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
# [8128 rows x 15 columns]

# %%
# Add year and month

jul_2017["Year"] = "2017"
jul_2017["Month"] = "July"

jul_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    675.649123  673.706140  668.429825
# 1    694.370968  659.693548  652.322581
# 2    679.433362  652.528310  644.569251
# 3    686.586957  690.652174  677.173913
# 4    712.683215  650.000000  600.000000
# ..          ...         ...         ...
# 7    692.583841  690.759146  690.741616
# 8    690.450000  690.000000  690.000000
# 9    686.192771  674.638554  690.000000
# 0    751.487603  773.363636  698.429752
# 1    733.000000  723.000000  693.000000
#
#                                   Identifier Country ProvinceState  \
# 0   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 1   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 2   fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3   364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# 4   c810efa572eb24b685d4ea14eb98d7f79cac0bd3      US            AK
# ..                                       ...     ...           ...
# 7   362159cb260bc35da7592691d97629ce9b8889ae      US            WV
# 8   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 9   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 0   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
# 1   a3a3fd48e1b69634ca3859998f7684d1593abcda      US            WY
#
#            City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0         Homer                    0     heat          hold    Home
# 1        Palmer                    0     heat          hold    Home
# 2       Wasilla                    0     heat          hold    Home
# 3        Palmer                    0     heat          auto    Home
# 4    North Pole                    0     heat          hold    Home
# ..          ...                  ...      ...           ...     ...
# 7   Martinsburg                    0     cool          hold    Home
# 8    Maidsville                    0     cool          hold    Home
# 9    Maidsville                    0     cool          auto    Home
# 0      Cheyenne                    0     cool          auto    Home
# 1      Cheyenne                    0     auto          auto    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0               True         False            False                       Gas
# 1              False         False            False                       Gas
# 2              False         False            False                       Gas
# 3              False         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 7              False         False             True                  Electric
# 8               True         False             True                  Electric
# 9               True         False             True                  Electric
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
#
#     Year Month
# 0   2017  July
# 1   2017  July
# 2   2017  July
# 3   2017  July
# 4   2017  July
# ..   ...   ...
# 7   2017  July
# 8   2017  July
# 9   2017  July
# 0   2017  July
# 1   2017  July
#
# [8128 rows x 17 columns]

# %% [markdown]
# ### 2017 August Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/aug/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
aug_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/aug/" + file)
    aug_2017 = pd.concat([aug_2017, df])
    
aug_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    721.333333  722.000000  719.333333
# 1    725.642857  692.035714  668.107143
# 2    669.857143  684.642857  682.285714
# 3    666.275641  673.346154  669.134615
# 4    689.200000  688.500000  670.900000
# ..          ...         ...         ...
# 2    694.679325  692.274262  679.983122
# 3    690.153662  689.515127  689.515127
# 4    691.965002  690.441437  670.000000
# 5    721.794473  720.690846  670.000000
# 6    721.768116  720.000000  670.000000
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 4   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a      US            AK
# ..                                       ...     ...           ...
# 2   ca71fafde08a023074581a58259413f3618418fb      US            WV
# 3   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 4   362159cb260bc35da7592691d97629ce9b8889ae      US            WV
# 5   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
# 6   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
#
#            City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0     Anchorage                    0     heat          auto    Home
# 1     Anchorage                    0     heat          hold    Home
# 2         Homer                    0     heat          auto    Home
# 3         Homer                    0     heat          hold    Home
# 4     Anchorage                    0     heat          auto    Home
# ..          ...                  ...      ...           ...     ...
# 2    Morgantown                    0     cool          auto    Home
# 3    Maidsville                    0     cool          hold    Home
# 4   Martinsburg                    0     cool          auto    Home
# 5    Morgantown                    0     auto          hold    Home
# 6    Morgantown                    0      off          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2               True         False            False                       Gas
# 3               True         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 2              False         False             True                  Electric
# 3               True         False             True                  Electric
# 4              False         False             True                  Electric
# 5              False         False            False                       Gas
# 6              False         False            False                       Gas
#
# [8170 rows x 15 columns]

# %%
# Add year and month

aug_2017["Year"] = "2017"
aug_2017["Month"] = "Aug"

aug_2017
# Out:
#     AvgTempCtrl     AvgCool     AvgHeat  \
# 0    721.333333  722.000000  719.333333
# 1    725.642857  692.035714  668.107143
# 2    669.857143  684.642857  682.285714
# 3    666.275641  673.346154  669.134615
# 4    689.200000  688.500000  670.900000
# ..          ...         ...         ...
# 2    694.679325  692.274262  679.983122
# 3    690.153662  689.515127  689.515127
# 4    691.965002  690.441437  670.000000
# 5    721.794473  720.690846  670.000000
# 6    721.768116  720.000000  670.000000
#
#                                   Identifier Country ProvinceState  \
# 0   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1   be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 2   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 3   0404ace1bcdf88d917bd860a04cd6c66fb51679f      US            AK
# 4   2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a      US            AK
# ..                                       ...     ...           ...
# 2   ca71fafde08a023074581a58259413f3618418fb      US            WV
# 3   7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 4   362159cb260bc35da7592691d97629ce9b8889ae      US            WV
# 5   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
# 6   23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
#
#            City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0     Anchorage                    0     heat          auto    Home
# 1     Anchorage                    0     heat          hold    Home
# 2         Homer                    0     heat          auto    Home
# 3         Homer                    0     heat          hold    Home
# 4     Anchorage                    0     heat          auto    Home
# ..          ...                  ...      ...           ...     ...
# 2    Morgantown                    0     cool          auto    Home
# 3    Maidsville                    0     cool          hold    Home
# 4   Martinsburg                    0     cool          auto    Home
# 5    Morgantown                    0     auto          hold    Home
# 6    Morgantown                    0      off          hold    Home
#
#     allowCompWithAux  Has_Electric  Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0              False         False            False                       Gas
# 1              False         False            False                       Gas
# 2               True         False            False                       Gas
# 3               True         False            False                       Gas
# 4              False         False            False                       Gas
# ..               ...           ...              ...                       ...
# 2              False         False             True                  Electric
# 3               True         False             True                  Electric
# 4              False         False             True                  Electric
# 5              False         False            False                       Gas
# 6              False         False            False                       Gas
#
#     Year Month
# 0   2017   Aug
# 1   2017   Aug
# 2   2017   Aug
# 3   2017   Aug
# 4   2017   Aug
# ..   ...   ...
# 2   2017   Aug
# 3   2017   Aug
# 4   2017   Aug
# 5   2017   Aug
# 6   2017   Aug
#
# [8170 rows x 17 columns]

# %% [markdown]
# ### 2017 September Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/sep/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
sep_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/sep/" + file)
    sep_2017 = pd.concat([sep_2017, df])
    
sep_2017
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add year and month

sep_2017["Year"] = "2017"
sep_2017["Month"] = "Sep"

sep_2017
# Out:
# Empty DataFrame
# Columns: [Year, Month]
# Index: []

# %% [markdown]
# ### 2017 October Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/oct/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
oct_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/oct/" + file)
    oct_2017 = pd.concat([oct_2017, df])
    
oct_2017
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add year and month

oct_2017["Year"] = "2017"
oct_2017["Month"] = "Oct"

oct_2017
# Out:
# Empty DataFrame
# Columns: [Year, Month]
# Index: []

# %% [markdown]
# ### 2017 November Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/nov/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
nov_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/nov/" + file)
    nov_2017 = pd.concat([nov_2017, df])
    
nov_2017
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add year and month

nov_2017["Year"] = "2017"
nov_2017["Month"] = "Nov"

nov_2017
# Out:
# Empty DataFrame
# Columns: [Year, Month]
# Index: []

# %% [markdown]
# ### 2017 December Day

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/day/2017/dec/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize and empty dataframe
dec_2017 = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/day/2017/dec/" + file)
    dec_2017 = pd.concat([dec_2017, df])
    
dec_2017
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add year and month

dec_2017["Year"] = "2017"
dec_2017["Month"] = "Dec"

dec_2017
# Out:
# Empty DataFrame
# Columns: [Year, Month]
# Index: []

# %% [markdown]
# ### Merge all 2017

# %%
All2017Day = jan_2017.append(feb_2017, ignore_index=True)
All2017Day = All2017Day.append(mar_2017, ignore_index=True)
All2017Day = All2017Day.append(apr_2017, ignore_index=True)
All2017Day = All2017Day.append(may_2017, ignore_index=True)
All2017Day = All2017Day.append(jun_2017, ignore_index=True)
All2017Day = All2017Day.append(jul_2017, ignore_index=True)
All2017Day = All2017Day.append(aug_2017, ignore_index=True)
All2017Day = All2017Day.append(sep_2017, ignore_index=True)
All2017Day = All2017Day.append(oct_2017, ignore_index=True)
All2017Day = All2017Day.append(nov_2017, ignore_index=True)
All2017Day = All2017Day.append(dec_2017, ignore_index=True)

# %%
All2017Day
# Out:
#        AvgTempCtrl     AvgCool     AvgHeat  \
# 0       674.860140  671.552448  665.972028
# 1       700.400000  697.600000  697.600000
# 2       689.749196  766.485531  685.254019
# 3       700.015385  703.780000  703.647692
# 4       644.954545  710.000000  710.000000
# ...            ...         ...         ...
# 59286   694.679325  692.274262  679.983122
# 59287   690.153662  689.515127  689.515127
# 59288   691.965002  690.441437  670.000000
# 59289   721.794473  720.690846  670.000000
# 59290   721.768116  720.000000  670.000000
#
#                                      Identifier Country ProvinceState  \
# 0      be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 1      be4f2a63b7719c2a69aa285e8a38038c29df8fa6      US            AK
# 2      fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 3      fda1f67e8423ed49933c45617ee96aef3bae04ba      US            AK
# 4      364d90d4305e64cf8a54685a3669aca9ba7667ed      US            AK
# ...                                         ...     ...           ...
# 59286  ca71fafde08a023074581a58259413f3618418fb      US            WV
# 59287  7249632b05298378ea9944b850b084262a1c3cf3      US            WV
# 59288  362159cb260bc35da7592691d97629ce9b8889ae      US            WV
# 59289  23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
# 59290  23ea815e8d635bf755b4f45c8594fba04bf97e35      US            WV
#
#               City  Age_of_Home__years_ HvacMode CalendarEvent Climate  \
# 0        Anchorage                  0.0     heat          auto    Home
# 1        Anchorage                  0.0     heat          hold    Home
# 2          Wasilla                  0.0     heat          auto    Home
# 3          Wasilla                  0.0     heat          hold    Home
# 4           Palmer                  0.0     heat          hold    Home
# ...            ...                  ...      ...           ...     ...
# 59286   Morgantown                  0.0     cool          auto    Home
# 59287   Maidsville                  0.0     cool          hold    Home
# 59288  Martinsburg                  0.0     cool          auto    Home
# 59289   Morgantown                  0.0     auto          hold    Home
# 59290   Morgantown                  0.0      off          hold    Home
#
#       allowCompWithAux Has_Electric Has_a_Heat_Pump Auxilliary_Heat_Fuel_Type  \
# 0                False        False           False                       Gas
# 1                False        False           False                       Gas
# 2                False        False           False                       Gas
# 3                False        False           False                       Gas
# 4                False        False           False                       Gas
# ...                ...          ...             ...                       ...
# 59286            False        False            True                  Electric
# 59287             True        False            True                  Electric
# 59288            False        False            True                  Electric
# 59289            False        False           False                       Gas
# 59290            False        False           False                       Gas
#
#        Year Month
# 0      2017   Jan
# 1      2017   Jan
# 2      2017   Jan
# 3      2017   Jan
# 4      2017   Jan
# ...     ...   ...
# 59286  2017   Aug
# 59287  2017   Aug
# 59288  2017   Aug
# 59289  2017   Aug
# 59290  2017   Aug
#
# [59291 rows x 17 columns]

# %%
All2017Day.to_csv("Scraper_Output/2017-states-0.csv", header=True, index=False)
