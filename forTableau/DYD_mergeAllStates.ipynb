# %% [markdown]
# # DYD Thermostat Data
#
# ### Combine month CSV Files
# 1. Read in files in folders for each state
# 2. Export as combined CSV to a folder not posted to GitHub due to file size

# %%
# Dependencies
import pandas as pd
import os
import numpy as np
from pathlib import Path
from datetime import datetime

# %%
# Create variable for files in directory
files = [f for f in os.listdir("data/") if f.endswith(".csv")]

# files

# %%
# https://stackoverflow.com/questions/63886787/how-to-create-a-dataframe-from-multiple-csv-files
# Initialize an empty dataframe
AllStates = pd.DataFrame()

# Iterate through files and contents, then concatenate the data into the dataframe
for file in files:
    df = pd.read_csv("data/" + file)
    AllStates = pd.concat([AllStates, df])
    
AllStates
# Out:
#                                     Identifier Month  Year HvacMode  \
# 0     0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 1     0404ace1bcdf88d917bd860a04cd6c66fb51679f   aug  2017     heat
# 2     1544f3165814ae017488964fc29ae302bba75bb7   aug  2017     heat
# 3     2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# 4     2a539ed50bd05f9b142b5b5a0c9cce50f5cf0e7a   aug  2017     heat
# ...                                        ...   ...   ...      ...
# 1480  f045e632eb732cd0703e069e70aef34bb8b50ad0   jun  2021     heat
# 1481  f3bd7952d2fbb216345ea8b272cbdee983b34ae6   jun  2021     cool
# 1482  f5be20356f7cafa6712707b496d91af1ddbdabe0   jun  2021     auto
# 1483  f5be20356f7cafa6712707b496d91af1ddbdabe0   jun  2021     cool
# 1484  f766ec9ff77cacb6b7c07ef6ac6a6f039c751748   jun  2021     auto
#
#      CalendarEvent       City  Temperature_ctrl_ave  \
# 0             auto      Homer            669.857143
# ...

# %%
AllStates.to_csv("../../data_large/AllStates.csv", header=True, index=False)

# %%
# Datacheck to make sure state was selected correctly in BQ sql queries

print(f"Unique states: {AllStates['State'].unique()}")
# Out:
# Unique states: ['AK' 'AL' 'AR' 'AZ' 'CA' 'CO' 'CT' 'DC' 'DE' 'FL' 'GA' 'HI' 'IA' 'ID'
#  'IL' 'IN' 'KS' 'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC'
#  'ND' 'NE' 'NH' 'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD'
#  'TN' 'TX' 'UT' 'VA' 'VT' 'WA' 'WI' 'WV' 'WY']
